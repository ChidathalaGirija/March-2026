# %%
name = "Girija"
name = name[0:3]+"v"+name[4:]
print(name)
# Out:
# Girvja

# %%
name = "Girija"
name = name[::-1]
print(name)
# Out:
# ajiriG

# %%
name = "i love you"
print(name * 3)
# Out:
# i love youi love youi love you

# %%
fruite = "apple"
print(fruite.count("a"))
# Out:
# 1

# %%
proposal = "o my friend"
print(proposal.find("i"))
# Out:
# 7

# %%
friendship = "o my friend"
print(friendship.index("e"))
# Out:
# 8

# %%
course_list = ("data engineering data science ml enginnering aure devops")
new_course_list = course_list.split(":"),course_list.replace("data","Data")
print(new_course_list)
# Out:
# (['data engineering data science ml enginnering aure devops'], 'Data engineering Data science ml enginnering aure devops')

# %%
course_list = ("data engineering data science ml enginnering aure devops")
funny_course_list = course_list.startswith("data"),course_list.endswith("s")
print(funny_course_list)
# Out:
# (True, True)

# %%
course_list = ["data engineering", "data science", "ml enginnering"," aure devops"]
course_list1 = " ".join (course_list)
print(course_list1)
# Out:
# data engineering data science ml enginnering  aure devops
