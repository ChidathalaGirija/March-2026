# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *
print("Spark environment and utilities successfully initialized!")
# Out:
# Spark environment and utilities successfully initialized!

# %%
#  SalesLT Address
address_schema = StructType([
    StructField("AddressID", IntegerType(), False),
    StructField("AddressLine1", StringType(), False),
    StructField("AddressLine2", StringType(), True),
    StructField("City", StringType(), False),
    StructField("StateProvince", StringType(), False),
    StructField("CountryRegion", StringType(), False),
    StructField("PostalCode", StringType(), False),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# %%
# SalesLT Customer
customer_schema = StructType([
    StructField("CustomerID", IntegerType(), False),
    StructField("NameStyle", BooleanType(), False),
    StructField("Title", StringType(), True),
    StructField("FirstName", StringType(), False),
    StructField("MiddleName", StringType(), True),
    StructField("LastName", StringType(), False),
    StructField("Suffix", StringType(), True),
    StructField("CompanyName", StringType(), True),
    StructField("SalesPerson", StringType(), True),
    StructField("EmailAddress", StringType(), True),
    StructField("Phone", StringType(), True),
    StructField("PasswordHash", StringType(), False),
    StructField("PasswordSalt", StringType(), False),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# %%
# SalesLT CustomerAddress
customer_address_schema = StructType([
    StructField("CustomerID", IntegerType(), False),
    StructField("AddressID", IntegerType(), False),
    StructField("AddressType", StringType(), False),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# %%
# SalesLT Product
product_schema = StructType([
    StructField("ProductID", IntegerType(), False),
    StructField("Name", StringType(), False),
    StructField("ProductNumber", StringType(), False),
    StructField("Color", StringType(), True),
    StructField("StandardCost", DecimalType(19, 4), False),
    StructField("ListPrice", DecimalType(19, 4), False),
    StructField("Size", StringType(), True),
    StructField("Weight", DecimalType(8, 2), True),
    StructField("ProductCategoryID", IntegerType(), True),
    StructField("ProductModelID", IntegerType(), True),
    StructField("SellStartDate", TimestampType(), False),
    StructField("SellEndDate", TimestampType(), True),
    StructField("DiscontinuedDate", TimestampType(), True),
    StructField("ThumbNailPhoto", BinaryType(), True),
    StructField("ThumbnailPhotoFileName", StringType(), True),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# %%
# SalesLT ProductCategory
product_category_schema = StructType([
    StructField("ProductCategoryID", IntegerType(), False),
    StructField("ParentProductCategoryID", IntegerType(), True),
    StructField("Name", StringType(), False),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# %%
# SalesLT ProductDescription
product_description_schema = StructType([
    StructField("ProductDescriptionID", IntegerType(), False),
    StructField("Description", StringType(), False),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# %%
# SalesLT ProductModel
product_model_schema = StructType([
    StructField("ProductModelID", IntegerType(), False),
    StructField("Name", StringType(), False),
    StructField("CatalogDescription", StringType(), True),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# %%
# SalesLT ProductModelProductDescription
product_model_description_schema = StructType([
    StructField("ProductModelID", IntegerType(), False),
    StructField("ProductDescriptionID", IntegerType(), False),
    StructField("Culture", StringType(), False),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# %%
# SalesLT SalesOrderHeader
sales_order_header_schema = StructType([
    StructField("SalesOrderID", IntegerType(), False),
    StructField("RevisionNumber", ByteType(), False),
    StructField("OrderDate", TimestampType(), False),
    StructField("DueDate", TimestampType(), False),
    StructField("ShipDate", TimestampType(), True),
    StructField("Status", ByteType(), False),
    StructField("OnlineOrderFlag", BooleanType(), False),
    StructField("SalesOrderNumber", StringType(), False),
    StructField("PurchaseOrderNumber", StringType(), True),
    StructField("AccountNumber", StringType(), True),
    StructField("CustomerID", IntegerType(), False),
    StructField("ShipToAddressID", IntegerType(), True),
    StructField("BillToAddressID", IntegerType(), True),
    StructField("ShipMethod", StringType(), False),
    StructField("CreditCardApprovalCode", StringType(), True),
    StructField("SubTotal", DecimalType(19, 4), False),
    StructField("TaxAmt", DecimalType(19, 4), False),
    StructField("Freight", DecimalType(19, 4), False),
    StructField("TotalDue", DecimalType(19, 4), False),
    StructField("Comment", StringType(), True),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# %%
# SalesLT SalesOrderDetail
sales_order_detail_schema = StructType([
    StructField("SalesOrderID", IntegerType(), False),
    StructField("SalesOrderDetailID", IntegerType(), False),
    StructField("OrderQty", ShortType(), False),
    StructField("ProductID", IntegerType(), False),
    StructField("UnitPrice", DecimalType(19, 4), False),
    StructField("UnitPriceDiscount", DecimalType(19, 4), False),
    StructField("LineTotal", DecimalType(38, 6), False),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# %%
# Create empty DataFrames
df_address = spark.createDataFrame([], address_schema)
df_customer = spark.createDataFrame([], customer_schema)
df_customer_address = spark.createDataFrame([], customer_address_schema)
df_product = spark.createDataFrame([], product_schema)
df_product_category = spark.createDataFrame([], product_category_schema)
df_product_description = spark.createDataFrame([], product_description_schema)
df_product_model = spark.createDataFrame([], product_model_schema)
df_product_model_description = spark.createDataFrame([], product_model_description_schema)
df_sales_order_header = spark.createDataFrame([], sales_order_header_schema)
df_sales_order_detail = spark.createDataFrame([], sales_order_detail_schema)

# %%
# Display schemas
df_address.printSchema()
df_customer.printSchema()
df_customer_address.printSchema()
df_product.printSchema()
df_product_category.printSchema()
df_product_description.printSchema()
df_product_model.printSchema()
df_product_model_description.printSchema()
df_sales_order_header.printSchema()
df_sales_order_detail.printSchema()
# Out:
# root
#  |-- AddressID: integer (nullable = false)
#  |-- AddressLine1: string (nullable = false)
#  |-- AddressLine2: string (nullable = true)
#  |-- City: string (nullable = false)
#  |-- StateProvince: string (nullable = false)
#  |-- CountryRegion: string (nullable = false)
#  |-- PostalCode: string (nullable = false)
#  |-- rowguid: string (nullable = false)
#  |-- ModifiedDate: timestamp (nullable = false)
#
# root
#  |-- CustomerID: integer (nullable = false)
#  |-- NameStyle: boolean (nullable = false)
#  |-- Title: string (nullable = true)
#  |-- FirstName: string (nullable = false)
#  |-- MiddleName: string (nullable = true)
#  |-- LastName: string (nullable = false)
#  |-- Suffix: string (nullable = true)
#  |-- CompanyName: string (nullable = true)
#  |-- SalesPerson: string (nullable = true)
#  |-- EmailAddress: string (nullable = true)
#  |-- Phone: string (nullable = true)
#  |-- PasswordHash: string (nullable = false)
#  |-- PasswordSalt: string (nullable = false)
#  |-- rowguid: string (nullable = false)
#  |-- ModifiedDate: timestamp (nullable = false)
#
# root
#  |-- CustomerID: integer (nullable = false)
#  |-- AddressID: integer (nullable = false)
#  |-- AddressType: string (nullable = false)
#  |-- rowguid: string (nullable = false)
#  |-- ModifiedDate: timestamp (nullable = false)
#
# root
#  |-- ProductID: integer (nullable = false)
#  |-- Name: string (nullable = false)
#  |-- ProductNumber: string (nullable = false)
#  |-- Color: string (nullable = true)
#  |-- StandardCost: decimal(19,4) (nullable = false)
#  |-- ListPrice: decimal(19,4) (nullable = false)
#  |-- Size: string (nullable = true)
#  |-- Weight: decimal(8,2) (nullable = true)
#  |-- ProductCategoryID: integer (nullable = true)
#  |-- ProductModelID: integer (nullable = true)
#  |-- SellStartDate: timestamp (nullable = false)
#  |-- SellEndDate: timestamp (nullable = true)
#  |-- DiscontinuedDate: timestamp (nullable = true)
#  |-- ThumbNailPhoto: binary (nullable = true)
#  |-- ThumbnailPhotoFileName: string (nullable = true)
#  |-- rowguid: string (nullable = false)
#  |-- ModifiedDate: timestamp (nullable = false)
#
# root
#  |-- ProductCategoryID: integer (nullable = false)
#  |-- ParentProductCategoryID: integer (nullable = true)
#  |-- Name: string (nullable = false)
#  |-- rowguid: string (nullable = false)
#  |-- ModifiedDate: timestamp (nullable = false)
#
# root
#  |-- ProductDescriptionID: integer (nullable = false)
#  |-- Description: string (nullable = false)
#  |-- rowguid: string (nullable = false)
#  |-- ModifiedDate: timestamp (nullable = false)
#
# root
#  |-- ProductModelID: integer (nullable = false)
#  |-- Name: string (nullable = false)
#  |-- CatalogDescription: string (nullable = true)
#  |-- rowguid: string (nullable = false)
#  |-- ModifiedDate: timestamp (nullable = false)
#
# root
#  |-- ProductModelID: integer (nullable = false)
#  |-- ProductDescriptionID: integer (nullable = false)
#  |-- Culture: string (nullable = false)
#  |-- rowguid: string (nullable = false)
#  |-- ModifiedDate: timestamp (nullable = false)
#
# root
#  |-- SalesOrderID: integer (nullable = false)
#  |-- RevisionNumber: byte (nullable = false)
#  |-- OrderDate: timestamp (nullable = false)
#  |-- DueDate: timestamp (nullable = false)
#  |-- ShipDate: timestamp (nullable = true)
#  |-- Status: byte (nullable = false)
#  |-- OnlineOrderFlag: boolean (nullable = false)
#  |-- SalesOrderNumber: string (nullable = false)
#  |-- PurchaseOrderNumber: string (nullable = true)
#  |-- AccountNumber: string (nullable = true)
#  |-- CustomerID: integer (nullable = false)
#  |-- ShipToAddressID: integer (nullable = true)
#  |-- BillToAddressID: integer (nullable = true)
#  |-- ShipMethod: string (nullable = false)
#  |-- CreditCardApprovalCode: string (nullable = true)
#  |-- SubTotal: decimal(19,4) (nullable = false)
#  |-- TaxAmt: decimal(19,4) (nullable = false)
#  |-- Freight: decimal(19,4) (nullable = false)
#  |-- TotalDue: decimal(19,4) (nullable = false)
#  |-- Comment: string (nullable = true)
#  |-- rowguid: string (nullable = false)
#  |-- ModifiedDate: timestamp (nullable = false)
#
# root
#  |-- SalesOrderID: integer (nullable = false)
#  |-- SalesOrderDetailID: integer (nullable = false)
#  |-- OrderQty: short (nullable = false)
#  |-- ProductID: integer (nullable = false)
#  |-- UnitPrice: decimal(19,4) (nullable = false)
#  |-- UnitPriceDiscount: decimal(19,4) (nullable = false)
#  |-- LineTotal: decimal(38,6) (nullable = false)
#  |-- rowguid: string (nullable = false)
#  |-- ModifiedDate: timestamp (nullable = false)

# %%
from pyspark.sql.types import *
from decimal import Decimal
from datetime import datetime

# %%
# 1. Address
# -------------------------------
address_schema = StructType([
    StructField("AddressID", IntegerType(), False),
    StructField("AddressLine1", StringType(), False),
    StructField("AddressLine2", StringType(), True),
    StructField("City", StringType(), False),
    StructField("StateProvince", StringType(), False),
    StructField("CountryRegion", StringType(), False),
    StructField("PostalCode", StringType(), False),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# %%
address_data = [
    (1, "1970 Napa Ct.", None, "Bothell", "Washington", "United States", "98011", "A1", datetime(2026,1,1)),
    (2, "9833 Mt. Dias Blv.", None, "Dallas", "Texas", "United States", "75201", "A2", datetime(2026,1,2)),
    (3, "7484 Roundtree Drive", None, "Toronto", "Ontario", "Canada", "M4B 1B3", "A3", datetime(2026,1,3)),
    (4, "9539 Glenside Dr", None, "London", "England", "United Kingdom", "EC1A 1BB", "A4", datetime(2026,1,4)),
    (5, "1226 Shoe St.", None, "Bangalore", "Karnataka", "India", "560001", "A5", datetime(2026,1,5))
]

# %%
df_address = spark.createDataFrame(address_data, address_schema)

# %%
# 2. Customer
# -------------------------------
customer_schema = StructType([
    StructField("CustomerID", IntegerType(), False),
    StructField("NameStyle", BooleanType(), False),
    StructField("Title", StringType(), True),
    StructField("FirstName", StringType(), False),
    StructField("MiddleName", StringType(), True),
    StructField("LastName", StringType(), False),
    StructField("Suffix", StringType(), True),
    StructField("CompanyName", StringType(), True),
    StructField("SalesPerson", StringType(), True),
    StructField("EmailAddress", StringType(), True),
    StructField("Phone", StringType(), True),
    StructField("PasswordHash", StringType(), False),
    StructField("PasswordSalt", StringType(), False),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# %%
customer_data = [
    (1, False, "Mr.", "Orlando", "N.", "Gee", None, "A Bike Store", "adventure-works\pamela0", "orlando@example.com", "245-555-0173", "hash1", "salt1", "C1", datetime(2026,1,1)),
    (2, False, "Mr.", "Keith", None, "Harris", None, "Progressive Sports", "adventure-works\david8", "keith@example.com", "170-555-0127", "hash2", "salt2", "C2", datetime(2026,1,2)),
    (3, False, "Ms.", "Donna", "F.", "Carreras", None, "Advanced Bike Components", "adventure-works\jillian0", "donna@example.com", "279-555-0130", "hash3", "salt3", "C3", datetime(2026,1,3)),
    (4, False, "Mr.", "Janeth", None, "Esteves", None, "Modular Cycle Systems", "adventure-works\garrett1", "janeth@example.com", "710-555-0173", "hash4", "salt4", "C4", datetime(2026,1,4)),
    (5, False, "Ms.", "Lucy", None, "Harrington", None, "Metropolitan Sports", "adventure-works\jillian0", "lucy@example.com", "828-555-0188", "hash5", "salt5", "C5", datetime(2026,1,5))
]
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\p'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:4: SyntaxWarning: invalid escape sequence '\j'
# <>:5: SyntaxWarning: invalid escape sequence '\g'
# <>:6: SyntaxWarning: invalid escape sequence '\j'
# <>:2: SyntaxWarning: invalid escape sequence '\p'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:4: SyntaxWarning: invalid escape sequence '\j'
# <>:5: SyntaxWarning: invalid escape sequence '\g'
# <>:6: SyntaxWarning: invalid escape sequence '\j'
# /home/spark-0c86a1e2-4c05-4679-8a8f-97/.ipykernel/10552/command-4930614754957401-2681791098:2: SyntaxWarning: invalid escape sequence '\p'
#   (1, False, "Mr.", "Orlando", "N.", "Gee", None, "A Bike Store", "adventure-works\pamela0", "orlando@example.com", "245-555-0173", "hash1", "salt1", "C1", datetime(2026,1,1)),
# /home/spark-0c86a1e2-4c05-4679-8a8f-97/.ipykernel/10552/command-4930614754957401-2681791098:3: SyntaxWarning: invalid escape sequence '\d'
#   (2, False, "Mr.", "Keith", None, "Harris", None, "Progressive Sports", "adventure-works\david8", "keith@example.com", "170-555-0127", "hash2", "salt2", "C2", datetime(2026,1,2)),
# /home/spark-0c86a1e2-4c05-4679-8a8f-97/.ipykernel/10552/command-4930614754957401-2681791098:4: SyntaxWarning: invalid escape sequence '\j'
#   (3, False, "Ms.", "Donna", "F.", "Carreras", None, "Advanced Bike Components", "adventure-works\jillian0", "donna@example.com", "279-555-0130", "hash3", "salt3", "C3", datetime(2026,1,3)),
# /home/spark-0c86a1e2-4c05-4679-8a8f-97/.ipykernel/10552/command-4930614754957401-2681791098:5: SyntaxWarning: invalid escape sequence '\g'
#   (4, False, "Mr.", "Janeth", None, "Esteves", None, "Modular Cycle Systems", "adventure-works\garrett1", "janeth@example.com", "710-555-0173", "hash4", "salt4", "C4", datetime(2026,1,4)),
# /home/spark-0c86a1e2-4c05-4679-8a8f-97/.ipykernel/10552/command-4930614754957401-2681791098:6: SyntaxWarning: invalid escape sequence '\j'
#   (5, False, "Ms.", "Lucy", None, "Harrington", None, "Metropolitan Sports", "adventure-works\jillian0", "lucy@example.com", "828-555-0188", "hash5", "salt5", "C5", datetime(2026,1,5))

# %%
df_customer = spark.createDataFrame(customer_data, customer_schema)

# %%
# 3. CustomerAddress
# -------------------------------
customer_address_schema = StructType([
    StructField("CustomerID", IntegerType(), False),
    StructField("AddressID", IntegerType(), False),
    StructField("AddressType", StringType(), False),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# %%
customer_address_data = [
    (1, 1, "Main Office", "CA1", datetime(2026,1,1)),
    (2, 2, "Shipping", "CA2", datetime(2026,1,2)),
    (3, 3, "Billing", "CA3", datetime(2026,1,3)),
    (4, 4, "Main Office", "CA4", datetime(2026,1,4)),
    (5, 5, "Shipping", "CA5", datetime(2026,1,5))
]

df_customer_address = spark.createDataFrame(customer_address_data, customer_address_schema)

# %%
# 4. ProductCategory
# -------------------------------
product_category_schema = StructType([
    StructField("ProductCategoryID", IntegerType(), False),
    StructField("ParentProductCategoryID", IntegerType(), True),
    StructField("Name", StringType(), False),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# %%
product_category_data = [
    (1, None, "Bikes", "PC1", datetime(2026,1,1)),
    (2, None, "Components", "PC2", datetime(2026,1,2)),
    (3, None, "Clothing", "PC3", datetime(2026,1,3)),
    (4, None, "Accessories", "PC4", datetime(2026,1,4)),
    (5, 1, "Mountain Bikes", "PC5", datetime(2026,1,5))
]

df_product_category = spark.createDataFrame(product_category_data, product_category_schema)

# %%
# 5. ProductModel
# -------------------------------
product_model_schema = StructType([
    StructField("ProductModelID", IntegerType(), False),
    StructField("Name", StringType(), False),
    StructField("CatalogDescription", StringType(), True),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# %%
product_model_data = [
    (1, "Classic Vest", "Lightweight vest model", "PM1", datetime(2026,1,1)),
    (2, "Mountain-100", "High performance mountain bike", "PM2", datetime(2026,1,2)),
    (3, "Road-150", "Road racing bike", "PM3", datetime(2026,1,3)),
    (4, "Touring-2000", "Touring bike model", "PM4", datetime(2026,1,4)),
    (5, "Sport Helmet", "Helmet model", "PM5", datetime(2026,1,5))
]

df_product_model = spark.createDataFrame(product_model_data, product_model_schema)

# %%
# 6. Product
# -------------------------------
product_schema = StructType([
    StructField("ProductID", IntegerType(), False),
    StructField("Name", StringType(), False),
    StructField("ProductNumber", StringType(), False),
    StructField("Color", StringType(), True),
    StructField("StandardCost", DecimalType(19,4), False),
    StructField("ListPrice", DecimalType(19,4), False),
    StructField("Size", StringType(), True),
    StructField("Weight", DecimalType(8,2), True),
    StructField("ProductCategoryID", IntegerType(), True),
    StructField("ProductModelID", IntegerType(), True),
    StructField("SellStartDate", TimestampType(), False),
    StructField("SellEndDate", TimestampType(), True),
    StructField("DiscontinuedDate", TimestampType(), True),
    StructField("ThumbNailPhoto", BinaryType(), True),
    StructField("ThumbnailPhotoFileName", StringType(), True),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# %%
product_data = [
    (1, "Mountain Bike", "BK-M68", "Black", Decimal("1200.00"), Decimal("2500.00"), "M", Decimal("15.50"), 5, 2, datetime(2026,1,1), None, None, None, "mountain.jpg", "P1", datetime(2026,1,1)),
    (2, "Road Bike", "BK-R79", "Red", Decimal("1500.00"), Decimal("3200.00"), "L", Decimal("12.80"), 1, 3, datetime(2026,1,2), None, None, None, "road.jpg", "P2", datetime(2026,1,2)),
    (3, "Touring Bike", "BK-T44", "Blue", Decimal("1000.00"), Decimal("2100.00"), "M", Decimal("14.20"), 1, 4, datetime(2026,1,3), None, None, None, "touring.jpg", "P3", datetime(2026,1,3)),
    (4, "Sport Helmet", "HL-U509", "Yellow", Decimal("20.00"), Decimal("49.99"), None, Decimal("1.20"), 4, 5, datetime(2026,1,4), None, None, None, "helmet.jpg", "P4", datetime(2026,1,4)),
    (5, "Classic Vest", "VE-C304", "Blue", Decimal("30.00"), Decimal("63.50"), "L", Decimal("0.80"), 3, 1, datetime(2026,1,5), None, None, None, "vest.jpg", "P5", datetime(2026,1,5))
]

df_product = spark.createDataFrame(product_data, product_schema)

# %%
# 7. ProductDescription
# -------------------------------
product_description_schema = StructType([
    StructField("ProductDescriptionID", IntegerType(), False),
    StructField("Description", StringType(), False),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# %%
product_description_data = [
    (1, "High quality mountain bike for rough roads", "PD1", datetime(2026,1,1)),
    (2, "Fast road bike for racing", "PD2", datetime(2026,1,2)),
    (3, "Comfortable touring bike", "PD3", datetime(2026,1,3)),
    (4, "Durable sport helmet", "PD4", datetime(2026,1,4)),
    (5, "Classic blue cycling vest", "PD5", datetime(2026,1,5))
]

df_product_description = spark.createDataFrame(product_description_data, product_description_schema)

# %%
# 8. ProductModelProductDescription
# -------------------------------
product_model_description_schema = StructType([
    StructField("ProductModelID", IntegerType(), False),
    StructField("ProductDescriptionID", IntegerType(), False),
    StructField("Culture", StringType(), False),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# %%
product_model_description_data = [
    (2, 1, "en", "PMPD1", datetime(2026,1,1)),
    (3, 2, "en", "PMPD2", datetime(2026,1,2)),
    (4, 3, "en", "PMPD3", datetime(2026,1,3)),
    (5, 4, "en", "PMPD4", datetime(2026,1,4)),
    (1, 5, "en", "PMPD5", datetime(2026,1,5))
]

df_product_model_description = spark.createDataFrame(product_model_description_data, product_model_description_schema)

# %%
# 9. SalesOrderHeader
# -------------------------------
sales_order_header_schema = StructType([
    StructField("SalesOrderID", IntegerType(), False),
    StructField("RevisionNumber", ByteType(), False),
    StructField("OrderDate", TimestampType(), False),
    StructField("DueDate", TimestampType(), False),
    StructField("ShipDate", TimestampType(), True),
    StructField("Status", ByteType(), False),
    StructField("OnlineOrderFlag", BooleanType(), False),
    StructField("SalesOrderNumber", StringType(), False),
    StructField("PurchaseOrderNumber", StringType(), True),
    StructField("AccountNumber", StringType(), True),
    StructField("CustomerID", IntegerType(), False),
    StructField("ShipToAddressID", IntegerType(), True),
    StructField("BillToAddressID", IntegerType(), True),
    StructField("ShipMethod", StringType(), False),
    StructField("CreditCardApprovalCode", StringType(), True),
    StructField("SubTotal", DecimalType(19,4), False),
    StructField("TaxAmt", DecimalType(19,4), False),
    StructField("Freight", DecimalType(19,4), False),
    StructField("TotalDue", DecimalType(19,4), False),
    StructField("Comment", StringType(), True),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# %%
sales_order_header_data = [
    (1001, 1, datetime(2026,2,1), datetime(2026,2,10), datetime(2026,2,5), 5, True, "SO1001", "PO1001", "10-4020-000001", 1, 1, 1, "CARGO TRANSPORT 5", "APPROVED", Decimal("2500.00"), Decimal("200.00"), Decimal("50.00"), Decimal("2750.00"), None, "SOH1", datetime(2026,2,1)),
    (1002, 1, datetime(2026,2,2), datetime(2026,2,11), datetime(2026,2,6), 5, True, "SO1002", "PO1002", "10-4020-000002", 2, 2, 2, "CARGO TRANSPORT 5", "APPROVED", Decimal("3200.00"), Decimal("256.00"), Decimal("70.00"), Decimal("3526.00"), None, "SOH2", datetime(2026,2,2)),
    (1003, 1, datetime(2026,2,3), datetime(2026,2,12), datetime(2026,2,7), 5, False, "SO1003", "PO1003", "10-4020-000003", 3, 3, 3, "CARGO TRANSPORT 5", "APPROVED", Decimal("2100.00"), Decimal("168.00"), Decimal("60.00"), Decimal("2328.00"), None, "SOH3", datetime(2026,2,3))
]

df_sales_order_header = spark.createDataFrame(sales_order_header_data, sales_order_header_schema)

# %%
# 10. SalesOrderDetail
# -------------------------------
sales_order_detail_schema = StructType([
    StructField("SalesOrderID", IntegerType(), False),
    StructField("SalesOrderDetailID", IntegerType(), False),
    StructField("OrderQty", ShortType(), False),
    StructField("ProductID", IntegerType(), False),
    StructField("UnitPrice", DecimalType(19,4), False),
    StructField("UnitPriceDiscount", DecimalType(19,4), False),
    StructField("LineTotal", DecimalType(38,6), False),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# %%
sales_order_detail_data = [
    (1001, 1, 1, 1, Decimal("2500.00"), Decimal("0.00"), Decimal("2500.000000"), "SOD1", datetime(2026,2,1)),
    (1002, 2, 1, 2, Decimal("3200.00"), Decimal("0.00"), Decimal("3200.000000"), "SOD2", datetime(2026,2,2)),
    (1003, 3, 1, 3, Decimal("2100.00"), Decimal("0.00"), Decimal("2100.000000"), "SOD3", datetime(2026,2,3)),
    (1001, 4, 2, 4, Decimal("49.99"), Decimal("0.00"), Decimal("99.980000"), "SOD4", datetime(2026,2,1)),
    (1002, 5, 3, 5, Decimal("63.50"), Decimal("0.00"), Decimal("190.500000"), "SOD5", datetime(2026,2,2))
]

df_sales_order_detail = spark.createDataFrame(sales_order_detail_data, sales_order_detail_schema)

# %%
# Display all tables
# -------------------------------
df_address.show(truncate=False)
df_customer.show(truncate=False)
df_customer_address.show(truncate=False)
df_product_category.show(truncate=False)
df_product_model.show(truncate=False)
df_product.show(truncate=False)
df_product_description.show(truncate=False)
df_product_model_description.show(truncate=False)
df_sales_order_header.show(truncate=False)
df_sales_order_detail.show(truncate=False)
# Out:
# +---------+--------------------+------------+---------+-------------+--------------+----------+-------+-------------------+
# |AddressID|AddressLine1        |AddressLine2|City     |StateProvince|CountryRegion |PostalCode|rowguid|ModifiedDate       |
# +---------+--------------------+------------+---------+-------------+--------------+----------+-------+-------------------+
# |1        |1970 Napa Ct.       |NULL        |Bothell  |Washington   |United States |98011     |A1     |2026-01-01 00:00:00|
# |2        |9833 Mt. Dias Blv.  |NULL        |Dallas   |Texas        |United States |75201     |A2     |2026-01-02 00:00:00|
# |3        |7484 Roundtree Drive|NULL        |Toronto  |Ontario      |Canada        |M4B 1B3   |A3     |2026-01-03 00:00:00|
# |4        |9539 Glenside Dr    |NULL        |London   |England      |United Kingdom|EC1A 1BB  |A4     |2026-01-04 00:00:00|
# |5        |1226 Shoe St.       |NULL        |Bangalore|Karnataka    |India         |560001    |A5     |2026-01-05 00:00:00|
# +---------+--------------------+------------+---------+-------------+--------------+----------+-------+-------------------+
#
# +----------+---------+-----+---------+----------+----------+------+------------------------+------------------------+-------------------+------------+------------+------------+-------+-------------------+
# |CustomerID|NameStyle|Title|FirstName|MiddleName|LastName  |Suffix|CompanyName             |SalesPerson             |EmailAddress       |Phone       |PasswordHash|PasswordSalt|rowguid|ModifiedDate       |
# +----------+---------+-----+---------+----------+----------+------+------------------------+------------------------+-------------------+------------+------------+------------+-------+-------------------+
# |1         |false    |Mr.  |Orlando  |N.        |Gee       |NULL  |A Bike Store            |adventure-works\pamela0 |orlando@example.com|245-555-0173|hash1       |salt1       |C1     |2026-01-01 00:00:00|
# |2         |false    |Mr.  |Keith    |NULL      |Harris    |NULL  |Progressive Sports      |adventure-works\david8  |keith@example.com  |170-555-0127|hash2       |salt2       |C2     |2026-01-02 00:00:00|
# |3         |false    |Ms.  |Donna    |F.        |Carreras  |NULL  |Advanced Bike Components|adventure-works\jillian0|donna@example.com  |279-555-0130|hash3       |salt3       |C3     |2026-01-03 00:00:00|
# |4         |false    |Mr.  |Janeth   |NULL      |Esteves   |NULL  |Modular Cycle Systems   |adventure-works\garrett1|janeth@example.com |710-555-0173|hash4       |salt4       |C4     |2026-01-04 00:00:00|
# |5         |false    |Ms.  |Lucy     |NULL      |Harrington|NULL  |Metropolitan Sports     |adventure-works\jillian0|lucy@example.com   |828-555-0188|hash5       |salt5       |C5     |2026-01-05 00:00:00|
# +----------+---------+-----+---------+----------+----------+------+------------------------+------------------------+-------------------+------------+------------+------------+-------+-------------------+
#
# +----------+---------+-----------+-------+-------------------+
# |CustomerID|AddressID|AddressType|rowguid|ModifiedDate       |
# +----------+---------+-----------+-------+-------------------+
# |1         |1        |Main Office|CA1    |2026-01-01 00:00:00|
# |2         |2        |Shipping   |CA2    |2026-01-02 00:00:00|
# |3         |3        |Billing    |CA3    |2026-01-03 00:00:00|
# |4         |4        |Main Office|CA4    |2026-01-04 00:00:00|
# |5         |5        |Shipping   |CA5    |2026-01-05 00:00:00|
# +----------+---------+-----------+-------+-------------------+
#
# +-----------------+-----------------------+--------------+-------+-------------------+
# |ProductCategoryID|ParentProductCategoryID|Name          |rowguid|ModifiedDate       |
# +-----------------+-----------------------+--------------+-------+-------------------+
# |1                |NULL                   |Bikes         |PC1    |2026-01-01 00:00:00|
# |2                |NULL                   |Components    |PC2    |2026-01-02 00:00:00|
# |3                |NULL                   |Clothing      |PC3    |2026-01-03 00:00:00|
# |4                |NULL                   |Accessories   |PC4    |2026-01-04 00:00:00|
# |5                |1                      |Mountain Bikes|PC5    |2026-01-05 00:00:00|
# +-----------------+-----------------------+--------------+-------+-------------------+
#
# +--------------+------------+------------------------------+-------+-------------------+
# |ProductModelID|Name        |CatalogDescription            |rowguid|ModifiedDate       |
# +--------------+------------+------------------------------+-------+-------------------+
# |1             |Classic Vest|Lightweight vest model        |PM1    |2026-01-01 00:00:00|
# |2             |Mountain-100|High performance mountain bike|PM2    |2026-01-02 00:00:00|
# |3             |Road-150    |Road racing bike              |PM3    |2026-01-03 00:00:00|
# |4             |Touring-2000|Touring bike model            |PM4    |2026-01-04 00:00:00|
# |5             |Sport Helmet|Helmet model                  |PM5    |2026-01-05 00:00:00|
# +--------------+------------+------------------------------+-------+-------------------+
#
# +---------+-------------+-------------+------+------------+---------+----+------+-----------------+--------------+-------------------+-----------+----------------+--------------+----------------------+-------+-------------------+
# |ProductID|Name         |ProductNumber|Color |StandardCost|ListPrice|Size|Weight|ProductCategoryID|ProductModelID|SellStartDate      |SellEndDate|DiscontinuedDate|ThumbNailPhoto|ThumbnailPhotoFileName|rowguid|ModifiedDate       |
# +---------+-------------+-------------+------+------------+---------+----+------+-----------------+--------------+-------------------+-----------+----------------+--------------+----------------------+-------+-------------------+
# |1        |Mountain Bike|BK-M68       |Black |1200.0000   |2500.0000|M   |15.50 |5                |2             |2026-01-01 00:00:00|NULL       |NULL            |NULL          |mountain.jpg          |P1     |2026-01-01 00:00:00|
# |2        |Road Bike    |BK-R79       |Red   |1500.0000   |3200.0000|L   |12.80 |1                |3             |2026-01-02 00:00:00|NULL       |NULL            |NULL          |road.jpg              |P2     |2026-01-02 00:00:00|
# |3        |Touring Bike |BK-T44       |Blue  |1000.0000   |2100.0000|M   |14.20 |1                |4             |2026-01-03 00:00:00|NULL       |NULL            |NULL          |touring.jpg           |P3     |2026-01-03 00:00:00|
# |4        |Sport Helmet |HL-U509      |Yellow|20.0000     |49.9900  |NULL|1.20  |4                |5             |2026-01-04 00:00:00|NULL       |NULL            |NULL          |helmet.jpg            |P4     |2026-01-04 00:00:00|
# |5        |Classic Vest |VE-C304      |Blue  |30.0000     |63.5000  |L   |0.80  |3                |1             |2026-01-05 00:00:00|NULL       |NULL            |NULL          |vest.jpg              |P5     |2026-01-05 00:00:00|
# +---------+-------------+-------------+------+------------+---------+----+------+-----------------+--------------+-------------------+-----------+----------------+--------------+----------------------+-------+-------------------+
#
# +--------------------+------------------------------------------+-------+-------------------+
# |ProductDescriptionID|Description                               |rowguid|ModifiedDate       |
# +--------------------+------------------------------------------+-------+-------------------+
# |1                   |High quality mountain bike for rough roads|PD1    |2026-01-01 00:00:00|
# |2                   |Fast road bike for racing                 |PD2    |2026-01-02 00:00:00|
# |3                   |Comfortable touring bike                  |PD3    |2026-01-03 00:00:00|
# |4                   |Durable sport helmet                      |PD4    |2026-01-04 00:00:00|
# |5                   |Classic blue cycling vest                 |PD5    |2026-01-05 00:00:00|
# +--------------------+------------------------------------------+-------+-------------------+
#
# +--------------+--------------------+-------+-------+-------------------+
# |ProductModelID|ProductDescriptionID|Culture|rowguid|ModifiedDate       |
# +--------------+--------------------+-------+-------+-------------------+
# |2             |1                   |en     |PMPD1  |2026-01-01 00:00:00|
# |3             |2                   |en     |PMPD2  |2026-01-02 00:00:00|
# |4             |3                   |en     |PMPD3  |2026-01-03 00:00:00|
# |5             |4                   |en     |PMPD4  |2026-01-04 00:00:00|
# |1             |5                   |en     |PMPD5  |2026-01-05 00:00:00|
# +--------------+--------------------+-------+-------+-------------------+
#
# +------------+--------------+-------------------+-------------------+-------------------+------+---------------+----------------+-------------------+--------------+----------+---------------+---------------+-----------------+----------------------+---------+--------+-------+---------+-------+-------+-------------------+
# |SalesOrderID|RevisionNumber|OrderDate          |DueDate            |ShipDate           |Status|OnlineOrderFlag|SalesOrderNumber|PurchaseOrderNumber|AccountNumber |CustomerID|ShipToAddressID|BillToAddressID|ShipMethod       |CreditCardApprovalCode|SubTotal |TaxAmt  |Freight|TotalDue |Comment|rowguid|ModifiedDate       |
# +------------+--------------+-------------------+-------------------+-------------------+------+---------------+----------------+-------------------+--------------+----------+---------------+---------------+-----------------+----------------------+---------+--------+-------+---------+-------+-------+-------------------+
# |1001        |1             |2026-02-01 00:00:00|2026-02-10 00:00:00|2026-02-05 00:00:00|5     |true           |SO1001          |PO1001             |10-4020-000001|1         |1              |1              |CARGO TRANSPORT 5|APPROVED              |2500.0000|200.0000|50.0000|2750.0000|NULL   |SOH1   |2026-02-01 00:00:00|
# |1002        |1             |2026-02-02 00:00:00|2026-02-11 00:00:00|2026-02-06 00:00:00|5     |true           |SO1002          |PO1002             |10-4020-000002|2         |2              |2              |CARGO TRANSPORT 5|APPROVED              |3200.0000|256.0000|70.0000|3526.0000|NULL   |SOH2   |2026-02-02 00:00:00|
# |1003        |1             |2026-02-03 00:00:00|2026-02-12 00:00:00|2026-02-07 00:00:00|5     |false          |SO1003          |PO1003             |10-4020-000003|3         |3              |3              |CARGO TRANSPORT 5|APPROVED              |2100.0000|168.0000|60.0000|2328.0000|NULL   |SOH3   |2026-02-03 00:00:00|
# +------------+--------------+-------------------+-------------------+-------------------+------+---------------+----------------+-------------------+--------------+----------+---------------+---------------+-----------------+----------------------+---------+--------+-------+---------+-------+-------+-------------------+
#
# +------------+------------------+--------+---------+---------+-----------------+-----------+-------+-------------------+
# |SalesOrderID|SalesOrderDetailID|OrderQty|ProductID|UnitPrice|UnitPriceDiscount|LineTotal  |rowguid|ModifiedDate       |
# +------------+------------------+--------+---------+---------+-----------------+-----------+-------+-------------------+
# |1001        |1                 |1       |1        |2500.0000|0.0000           |2500.000000|SOD1   |2026-02-01 00:00:00|
# |1002        |2                 |1       |2        |3200.0000|0.0000           |3200.000000|SOD2   |2026-02-02 00:00:00|
# |1003        |3                 |1       |3        |2100.0000|0.0000           |2100.000000|SOD3   |2026-02-03 00:00:00|
# |1001        |4                 |2       |4        |49.9900  |0.0000           |99.980000  |SOD4   |2026-02-01 00:00:00|
# |1002        |5                 |3       |5        |63.5000  |0.0000           |190.500000 |SOD5   |2026-02-02 00:00:00|
# +------------+------------------+--------+---------+---------+-----------------+-----------+-------+-------------------+

# %%
# Check the product table data
df_product.show(truncate=False)

# Check the sales order details
df_sales_order_detail.show(truncate=False)
# Out:
# +---------+-------------+-------------+------+------------+---------+----+------+-----------------+--------------+-------------------+-----------+----------------+--------------+----------------------+-------+-------------------+
# |ProductID|Name         |ProductNumber|Color |StandardCost|ListPrice|Size|Weight|ProductCategoryID|ProductModelID|SellStartDate      |SellEndDate|DiscontinuedDate|ThumbNailPhoto|ThumbnailPhotoFileName|rowguid|ModifiedDate       |
# +---------+-------------+-------------+------+------------+---------+----+------+-----------------+--------------+-------------------+-----------+----------------+--------------+----------------------+-------+-------------------+
# |1        |Mountain Bike|BK-M68       |Black |1200.0000   |2500.0000|M   |15.50 |5                |2             |2026-01-01 00:00:00|NULL       |NULL            |NULL          |mountain.jpg          |P1     |2026-01-01 00:00:00|
# |2        |Road Bike    |BK-R79       |Red   |1500.0000   |3200.0000|L   |12.80 |1                |3             |2026-01-02 00:00:00|NULL       |NULL            |NULL          |road.jpg              |P2     |2026-01-02 00:00:00|
# |3        |Touring Bike |BK-T44       |Blue  |1000.0000   |2100.0000|M   |14.20 |1                |4             |2026-01-03 00:00:00|NULL       |NULL            |NULL          |touring.jpg           |P3     |2026-01-03 00:00:00|
# |4        |Sport Helmet |HL-U509      |Yellow|20.0000     |49.9900  |NULL|1.20  |4                |5             |2026-01-04 00:00:00|NULL       |NULL            |NULL          |helmet.jpg            |P4     |2026-01-04 00:00:00|
# |5        |Classic Vest |VE-C304      |Blue  |30.0000     |63.5000  |L   |0.80  |3                |1             |2026-01-05 00:00:00|NULL       |NULL            |NULL          |vest.jpg              |P5     |2026-01-05 00:00:00|
# +---------+-------------+-------------+------+------------+---------+----+------+-----------------+--------------+-------------------+-----------+----------------+--------------+----------------------+-------+-------------------+
#
# +------------+------------------+--------+---------+---------+-----------------+-----------+-------+-------------------+
# |SalesOrderID|SalesOrderDetailID|OrderQty|ProductID|UnitPrice|UnitPriceDiscount|LineTotal  |rowguid|ModifiedDate       |
# +------------+------------------+--------+---------+---------+-----------------+-----------+-------+-------------------+
# |1001        |1                 |1       |1        |2500.0000|0.0000           |2500.000000|SOD1   |2026-02-01 00:00:00|
# |1002        |2                 |1       |2        |3200.0000|0.0000           |3200.000000|SOD2   |2026-02-02 00:00:00|
# |1003        |3                 |1       |3        |2100.0000|0.0000           |2100.000000|SOD3   |2026-02-03 00:00:00|
# |1001        |4                 |2       |4        |49.9900  |0.0000           |99.980000  |SOD4   |2026-02-01 00:00:00|
# |1002        |5                 |3       |5        |63.5000  |0.0000           |190.500000 |SOD5   |2026-02-02 00:00:00|
# +------------+------------------+--------+---------+---------+-----------------+-----------+-------+-------------------+

# %%
display(df_sales_order_header)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>SalesOrderID</th><th>RevisionNumber</th><th>OrderDate</th><th>DueDate</th><th>ShipDate</th><th>Status</th><th>OnlineOrderFlag</th><th>SalesOrderNumber</th><th>PurchaseOrderNumber</th><th>AccountNumber</th><th>CustomerID</th><th>ShipToAddressID</th><th>BillToAddressID</th><th>ShipMethod</th><th>CreditCardApprovalCode</th><th>SubTotal</th><th>TaxAmt</th><th>Freight</th><th>TotalDue</th><th>Comment</th><th>rowguid</th><th>ModifiedDate</th></tr></thead><tbody><tr><td>1001</td><td>1</td><td>2026-02-01T00:00:00.000Z</td><td>2026-02-10T00:00:00.000Z</td><td>2026-02-05T00:00:00.000Z</td><td>5</td><td>true</td><td>SO1001</td><td>PO1001</td><td>10-4020-000001</td><td>1</td><td>1</td><td>1</td><td>CARGO TRANSPORT 5</td><td>APPROVED</td><td>2500.0000</td><td>200.0000</td><td>50.0000</td><td>2750.0000</td><td>null</td><td>SOH1</td><td>2026-02-01T00:00:00.000Z</td></tr><tr><td>1002</td><td>1</td><td>2026-02-02T00:00:00.000Z</td><td>2026-02-11T00:00:00.000Z</td><td>2026-02-06T00:00:00.000Z</td><td>5</td><td>true</td><td>SO1002</td><td>PO1002</td><td>10-4020-000002</td><td>2</td><td>2</td><td>2</td><td>CARGO TRANSPORT 5</td><td>APPROVED</td><td>3200.0000</td><td>256.0000</td><td>70.0000</td><td>3526.0000</td><td>null</td><td>SOH2</td><td>2026-02-02T00:00:00.000Z</td></tr><tr><td>1003</td><td>1</td><td>2026-02-03T00:00:00.000Z</td><td>2026-02-12T00:00:00.000Z</td><td>2026-02-07T00:00:00.000Z</td><td>5</td><td>false</td><td>SO1003</td><td>PO1003</td><td>10-4020-000003</td><td>3</td><td>3</td><td>3</td><td>CARGO TRANSPORT 5</td><td>APPROVED</td><td>2100.0000</td><td>168.0000</td><td>60.0000</td><td>2328.0000</td><td>null</td><td>SOH3</td><td>2026-02-03T00:00:00.000Z</td></tr></tbody></table></div>

# %%
df_sales_order_detail.printSchema()
# Out:
# root
#  |-- SalesOrderID: integer (nullable = false)
#  |-- SalesOrderDetailID: integer (nullable = false)
#  |-- OrderQty: short (nullable = false)
#  |-- ProductID: integer (nullable = false)
#  |-- UnitPrice: decimal(19,4) (nullable = false)
#  |-- UnitPriceDiscount: decimal(19,4) (nullable = false)
#  |-- LineTotal: decimal(38,6) (nullable = false)
#  |-- rowguid: string (nullable = false)
#  |-- ModifiedDate: timestamp (nullable = false)

# %%
# BRONZE LAYER TASKS
# Import Dependencies and Map DataFrames
from pyspark.sql.functions import current_timestamp, lit, col
import datetime
bronze_tables = {
    "address": df_address,
    "customer": df_customer,
    "customer_address": df_customer_address,
    "product": df_product,
    "product_category": df_product_category,
    "product_description": df_product_description,
    "product_model": df_product_model,
    "product_model_description": df_product_model_description,
    "sales_order_header": df_sales_order_header,
    "sales_order_detail": df_sales_order_detail
}
print("Dependencies imported and DataFrame mapping completed.")
# Out:
# Dependencies imported and DataFrame mapping completed.

# %%
from pyspark.sql.types import *
from pyspark.sql.functions import current_timestamp, lit, col
from decimal import Decimal
import datetime

print("Cell 1 Complete: Dependencies and environment initialized.")
# Out:
# Cell 1 Complete: Dependencies and environment initialized.

# %%
# 1. Address
address_schema = StructType([
    StructField("AddressID", IntegerType(), False),
    StructField("AddressLine1", StringType(), False),
    StructField("AddressLine2", StringType(), True),
    StructField("City", StringType(), False),
    StructField("StateProvince", StringType(), False),
    StructField("CountryRegion", StringType(), False),
    StructField("PostalCode", StringType(), False),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# %%
address_data = [
    (1, "1970 Napa Ct.", None, "Bothell", "Washington", "United States", "98011", "A1", datetime.datetime(2026,1,1)),
    (2, "9833 Mt. Dias Blv.", None, "Dallas", "Texas", "United States", "75201", "A2", datetime.datetime(2026,1,2)),
    (3, "7484 Roundtree Drive", None, "Toronto", "Ontario", "Canada", "M4B 1B3", "A3", datetime.datetime(2026,1,3)),
    (4, "9539 Glenside Dr", None, "London", "England", "United Kingdom", "EC1A 1BB", "A4", datetime.datetime(2026,1,4)),
    (5, "1226 Shoe St.", None, "Bangalore", "Karnataka", "India", "560001", "A5", datetime.datetime(2026,1,5))
]
df_address = spark.createDataFrame(address_data, address_schema)

# %%
# 2. Customer
customer_schema = StructType([
    StructField("CustomerID", IntegerType(), False),
    StructField("NameStyle", BooleanType(), False),
    StructField("Title", StringType(), True),
    StructField("FirstName", StringType(), False),
    StructField("MiddleName", StringType(), True),
    StructField("LastName", StringType(), False),
    StructField("Suffix", StringType(), True),
    StructField("CompanyName", StringType(), True),
    StructField("SalesPerson", StringType(), True),
    StructField("EmailAddress", StringType(), True),
    StructField("Phone", StringType(), True),
    StructField("PasswordHash", StringType(), False),
    StructField("PasswordSalt", StringType(), False),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# %%
customer_data = [
    (1, False, "Mr.", "Orlando", "N.", "Gee", None, "A Bike Store", "adventure-works\pamela0", "orlando@example.com", "245-555-0173", "hash1", "salt1", "C1", datetime.datetime(2026,1,1)),
    (2, False, "Mr.", "Keith", None, "Harris", None, "Progressive Sports", "adventure-works\david8", "keith@example.com", "170-555-0127", "hash2", "salt2", "C2", datetime.datetime(2026,1,2)),
    (3, False, "Ms.", "Donna", "F.", "Carreras", None, "Advanced Bike Components", "adventure-works\jillian0", "donna@example.com", "279-555-0130", "hash3", "salt3", "C3", datetime.datetime(2026,1,3)),
    (4, False, "Mr.", "Janeth", None, "Esteves", None, "Modular Cycle Systems", "adventure-works\garrett1", "janeth@example.com", "710-555-0173", "hash4", "salt4", "C4", datetime.datetime(2026,1,4)),
    (5, False, "Ms.", "Lucy", None, "Harrington", None, "Metropolitan Sports", "adventure-works\jillian0", "lucy@example.com", "828-555-0188", "hash5", "salt5", "C5", datetime.datetime(2026,1,5))
]
df_customer = spark.createDataFrame(customer_data, customer_schema)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\p'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:4: SyntaxWarning: invalid escape sequence '\j'
# <>:5: SyntaxWarning: invalid escape sequence '\g'
# <>:6: SyntaxWarning: invalid escape sequence '\j'
# <>:2: SyntaxWarning: invalid escape sequence '\p'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:4: SyntaxWarning: invalid escape sequence '\j'
# <>:5: SyntaxWarning: invalid escape sequence '\g'
# <>:6: SyntaxWarning: invalid escape sequence '\j'
# /home/spark-0c86a1e2-4c05-4679-8a8f-97/.ipykernel/10552/command-4930614754957428-1067132612:2: SyntaxWarning: invalid escape sequence '\p'
#   (1, False, "Mr.", "Orlando", "N.", "Gee", None, "A Bike Store", "adventure-works\pamela0", "orlando@example.com", "245-555-0173", "hash1", "salt1", "C1", datetime.datetime(2026,1,1)),
# /home/spark-0c86a1e2-4c05-4679-8a8f-97/.ipykernel/10552/command-4930614754957428-1067132612:3: SyntaxWarning: invalid escape sequence '\d'
#   (2, False, "Mr.", "Keith", None, "Harris", None, "Progressive Sports", "adventure-works\david8", "keith@example.com", "170-555-0127", "hash2", "salt2", "C2", datetime.datetime(2026,1,2)),
# /home/spark-0c86a1e2-4c05-4679-8a8f-97/.ipykernel/10552/command-4930614754957428-1067132612:4: SyntaxWarning: invalid escape sequence '\j'
#   (3, False, "Ms.", "Donna", "F.", "Carreras", None, "Advanced Bike Components", "adventure-works\jillian0", "donna@example.com", "279-555-0130", "hash3", "salt3", "C3", datetime.datetime(2026,1,3)),
# /home/spark-0c86a1e2-4c05-4679-8a8f-97/.ipykernel/10552/command-4930614754957428-1067132612:5: SyntaxWarning: invalid escape sequence '\g'
#   (4, False, "Mr.", "Janeth", None, "Esteves", None, "Modular Cycle Systems", "adventure-works\garrett1", "janeth@example.com", "710-555-0173", "hash4", "salt4", "C4", datetime.datetime(2026,1,4)),
# /home/spark-0c86a1e2-4c05-4679-8a8f-97/.ipykernel/10552/command-4930614754957428-1067132612:6: SyntaxWarning: invalid escape sequence '\j'
#   (5, False, "Ms.", "Lucy", None, "Harrington", None, "Metropolitan Sports", "adventure-works\jillian0", "lucy@example.com", "828-555-0188", "hash5", "salt5", "C5", datetime.datetime(2026,1,5))
# <unknown>:2: SyntaxWarning: invalid escape sequence '\p'
# <unknown>:3: SyntaxWarning: invalid escape sequence '\d'
# <unknown>:4: SyntaxWarning: invalid escape sequence '\j'
# <unknown>:5: SyntaxWarning: invalid escape sequence '\g'
# <unknown>:6: SyntaxWarning: invalid escape sequence '\j'

# %%
# 3. CustomerAddress
customer_address_schema = StructType([
    StructField("CustomerID", IntegerType(), False),
    StructField("AddressID", IntegerType(), False),
    StructField("AddressType", StringType(), False),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])
customer_address_data = [
    (1, 1, "Main Office", "CA1", datetime.datetime(2026,1,1)),
    (2, 2, "Shipping", "CA2", datetime.datetime(2026,1,2)),
    (3, 3, "Billing", "CA3", datetime.datetime(2026,1,3)),
    (4, 4, "Main Office", "CA4", datetime.datetime(2026,1,4)),
    (5, 5, "Shipping", "CA5", datetime.datetime(2026,1,5))
]
df_customer_address = spark.createDataFrame(customer_address_data, customer_address_schema)

# %%
# 4. ProductCategory
product_category_schema = StructType([
    StructField("ProductCategoryID", IntegerType(), False),
    StructField("ParentProductCategoryID", IntegerType(), True),
    StructField("Name", StringType(), False),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])
product_category_data = [
    (1, None, "Bikes", "PC1", datetime.datetime(2026,1,1)),
    (2, None, "Components", "PC2", datetime.datetime(2026,1,2)),
    (3, None, "Clothing", "PC3", datetime.datetime(2026,1,3)),
    (4, None, "Accessories", "PC4", datetime.datetime(2026,1,4)),
    (5, 1, "Mountain Bikes", "PC5", datetime.datetime(2026,1,5))
]
df_product_category = spark.createDataFrame(product_category_data, product_category_schema)

# %%
# 5. ProductModel
product_model_schema = StructType([
    StructField("ProductModelID", IntegerType(), False),
    StructField("Name", StringType(), False),
    StructField("CatalogDescription", StringType(), True),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])
product_model_data = [
    (1, "Classic Vest", "Lightweight vest model", "PM1", datetime.datetime(2026,1,1)),
    (2, "Mountain-100", "High performance mountain bike", "PM2", datetime.datetime(2026,1,2)),
    (3, "Road-150", "Road racing bike", "PM3", datetime.datetime(2026,1,3)),
    (4, "Touring-2000", "Touring bike model", "PM4", datetime.datetime(2026,1,4)),
    (5, "Sport Helmet", "Helmet model", "PM5", datetime.datetime(2026,1,5))
]
df_product_model = spark.createDataFrame(product_model_data, product_model_schema)

# %%
# 6. Product
product_schema = StructType([
    StructField("ProductID", IntegerType(), False),
    StructField("Name", StringType(), False),
    StructField("ProductNumber", StringType(), False),
    StructField("Color", StringType(), True),
    StructField("StandardCost", DecimalType(19,4), False),
    StructField("ListPrice", DecimalType(19,4), False),
    StructField("Size", StringType(), True),
    StructField("Weight", DecimalType(8,2), True),
    StructField("ProductCategoryID", IntegerType(), True),
    StructField("ProductModelID", IntegerType(), True),
    StructField("SellStartDate", TimestampType(), False),
    StructField("SellEndDate", TimestampType(), True),
    StructField("DiscontinuedDate", TimestampType(), True),
    StructField("ThumbNailPhoto", BinaryType(), True),
    StructField("ThumbnailPhotoFileName", StringType(), True),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])
product_data = [
    (1, "Mountain Bike", "BK-M68", "Black", Decimal("1200.00"), Decimal("2500.00"), "M", Decimal("15.50"), 5, 2, datetime.datetime(2026,1,1), None, None, None, "mountain.jpg", "P1", datetime.datetime(2026,1,1)),
    (2, "Road Bike", "BK-R79", "Red", Decimal("1500.00"), Decimal("3200.00"), "L", Decimal("12.80"), 1, 3, datetime.datetime(2026,1,2), None, None, None, "road.jpg", "P2", datetime.datetime(2026,1,2)),
    (3, "Touring Bike", "BK-T44", "Blue", Decimal("1000.00"), Decimal("2100.00"), "M", Decimal("14.20"), 1, 4, datetime.datetime(2026,1,3), None, None, None, "touring.jpg", "P3", datetime.datetime(2026,1,3)),
    (4, "Sport Helmet", "HL-U509", "Yellow", Decimal("20.00"), Decimal("49.99"), None, Decimal("1.20"), 4, 5, datetime.datetime(2026,1,4), None, None, None, "helmet.jpg", "P4", datetime.datetime(2026,1,4)),
    (5, "Classic Vest", "VE-C304", "Blue", Decimal("30.00"), Decimal("63.50"), "L", Decimal("0.80"), 3, 1, datetime.datetime(2026,1,5), None, None, None, "vest.jpg", "P5", datetime.datetime(2026,1,5))
]
df_product = spark.createDataFrame(product_data, product_schema)

# %%
# 7. ProductDescription
product_description_schema = StructType([
    StructField("ProductDescriptionID", IntegerType(), False),
    StructField("Description", StringType(), False),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])
product_description_data = [
    (1, "High quality mountain bike for rough roads", "PD1", datetime.datetime(2026,1,1)),
    (2, "Fast road bike for racing", "PD2", datetime.datetime(2026,1,2)),
    (3, "Comfortable touring bike", "PD3", datetime.datetime(2026,1,3)),
    (4, "Durable sport helmet", "PD4", datetime.datetime(2026,1,4)),
    (5, "Classic blue cycling vest", "PD5", datetime.datetime(2026,1,5))
]
df_product_description = spark.createDataFrame(product_description_data, product_description_schema)

# %%
# 8. ProductModelProductDescription
product_model_description_schema = StructType([
    StructField("ProductModelID", IntegerType(), False),
    StructField("ProductDescriptionID", IntegerType(), False),
    StructField("Culture", StringType(), False),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])
product_model_description_data = [
    (2, 1, "en", "PMPD1", datetime.datetime(2026,1,1)),
    (3, 2, "en", "PMPD2", datetime.datetime(2026,1,2)),
    (4, 3, "en", "PMPD3", datetime.datetime(2026,1,3)),
    (5, 4, "en", "PMPD4", datetime.datetime(2026,1,4)),
    (1, 5, "en", "PMPD5", datetime.datetime(2026,1,5))
]
df_product_model_description = spark.createDataFrame(product_model_description_data, product_model_description_schema)

# %%
# 9. SalesOrderHeader
sales_order_header_schema = StructType([
    StructField("SalesOrderID", IntegerType(), False),
    StructField("RevisionNumber", ByteType(), False),
    StructField("OrderDate", TimestampType(), False),
    StructField("DueDate", TimestampType(), False),
    StructField("ShipDate", TimestampType(), True),
    StructField("Status", ByteType(), False),
    StructField("OnlineOrderFlag", BooleanType(), False),
    StructField("SalesOrderNumber", StringType(), False),
    StructField("PurchaseOrderNumber", StringType(), True),
    StructField("AccountNumber", StringType(), True),
    StructField("CustomerID", IntegerType(), False),
    StructField("ShipToAddressID", IntegerType(), True),
    StructField("BillToAddressID", IntegerType(), True),
    StructField("ShipMethod", StringType(), False),
    StructField("CreditCardApprovalCode", StringType(), True),
    StructField("SubTotal", DecimalType(19,4), False),
    StructField("TaxAmt", DecimalType(19,4), False),
    StructField("Freight", DecimalType(19,4), False),
    StructField("TotalDue", DecimalType(19,4), False),
    StructField("Comment", StringType(), True),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])
sales_order_header_data = [
    (1001, 1, datetime.datetime(2026,2,1), datetime.datetime(2026,2,10), datetime.datetime(2026,2,5), 5, True, "SO1001", "PO1001", "10-4020-000001", 1, 1, 1, "CARGO TRANSPORT 5", "APPROVED", Decimal("2500.00"), Decimal("200.00"), Decimal("50.00"), Decimal("2750.00"), None, "SOH1", datetime.datetime(2026,2,1)),
    (1002, 1, datetime.datetime(2026,2,2), datetime.datetime(2026,2,11), datetime.datetime(2026,2,6), 5, True, "SO1002", "PO1002", "10-4020-000002", 2, 2, 2, "CARGO TRANSPORT 5", "APPROVED", Decimal("3200.00"), Decimal("256.00"), Decimal("70.00"), Decimal("3526.00"), None, "SOH2", datetime.datetime(2026,2,2)),
    (1003, 1, datetime.datetime(2026,2,3), datetime.datetime(2026,2,12), datetime.datetime(2026,2,7), 5, False, "SO1003", "PO1003", "10-4020-000003", 3, 3, 3, "CARGO TRANSPORT 5", "APPROVED", Decimal("2100.00"), Decimal("168.00"), Decimal("60.00"), Decimal("2328.00"), None, "SOH3", datetime.datetime(2026,2,3))
]
df_sales_order_header = spark.createDataFrame(sales_order_header_data, sales_order_header_schema)

# %%
# 10. SalesOrderDetail
sales_order_detail_schema = StructType([
    StructField("SalesOrderID", IntegerType(), False),
    StructField("SalesOrderDetailID", IntegerType(), False),
    StructField("OrderQty", ShortType(), False),
    StructField("ProductID", IntegerType(), False),
    StructField("UnitPrice", DecimalType(19,4), False),
    StructField("UnitPriceDiscount", DecimalType(19,4), False),
    StructField("LineTotal", DecimalType(38,6), False),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])
sales_order_detail_data = [
    (1001, 1, 1, 1, Decimal("2500.00"), Decimal("0.00"), Decimal("2500.000000"), "SOD1", datetime.datetime(2026,2,1)),
    (1002, 2, 1, 2, Decimal("3200.00"), Decimal("0.00"), Decimal("3200.000000"), "SOD2", datetime.datetime(2026,2,2)),
    (1003, 3, 1, 3, Decimal("2100.00"), Decimal("0.00"), Decimal("2100.000000"), "SOD3", datetime.datetime(2026,2,3)),
    (1001, 4, 2, 4, Decimal("49.99"), Decimal("0.00"), Decimal("99.980000"), "SOD4", datetime.datetime(2026,2,1)),
    (1002, 5, 3, 5, Decimal("63.50"), Decimal("0.00"), Decimal("190.500000"), "SOD5", datetime.datetime(2026,2,2))
]
df_sales_order_detail = spark.createDataFrame(sales_order_detail_data, sales_order_detail_schema)

# %%
bronze_tables = {
    "address": df_address,
    "customer": df_customer,
    "customer_address": df_customer_address,
    "product": df_product,
    "product_category": df_product_category,
    "product_description": df_product_description,
    "product_model": df_product_model,
    "product_model_description": df_product_model_description,
    "sales_order_header": df_sales_order_header,
    "sales_order_detail": df_sales_order_detail
}
print("Cell 2 Complete: Source data and schemas mapped.")
# Out:
# Cell 2 Complete: Source data and schemas mapped.

# %%
import datetime
from pyspark.sql.types import *

# %%
# 1. Address 

address_schema = StructType([
    StructField("AddressID", IntegerType(), False),
    StructField("AddressLine1", StringType(), False),
    StructField("AddressLine2", StringType(), True),
    StructField("City", StringType(), False),
    StructField("StateProvince", StringType(), False),
    StructField("CountryRegion", StringType(), False),
    StructField("PostalCode", StringType(), False),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

address_data = [
    (1, "1970 Napa Ct.", None, "Bothell", "Washington", "United States", "98011", "A1", datetime.datetime(2026,1,1)),
    (2, "9833 Mt. Dias Blv.", None, "Dallas", "Texas", "United States", "75201", "A2", datetime.datetime(2026,1,2)),
    (3, "7484 Roundtree Drive", None, "Toronto", "Ontario", "Canada", "M4B 1B3", "A3", datetime.datetime(2026,1,3)),
    (4, "9539 Glenside Dr", None, "London", "England", "United Kingdom", "EC1A 1BB", "A4", datetime.datetime(2026,1,4)),
    (5, "1226 Shoe St.", None, "Bangalore", "Karnataka", "India", "560001", "A5", datetime.datetime(2026,1,5))
]
df_address = spark.createDataFrame(address_data, address_schema)

# %%
# 2. Customer (Your provided snippet)
# ==========================================
customer_schema = StructType([
    StructField("CustomerID", IntegerType(), False),
    StructField("NameStyle", BooleanType(), False),
    StructField("Title", StringType(), True),
    StructField("FirstName", StringType(), False),
    StructField("MiddleName", StringType(), True),
    StructField("LastName", StringType(), False),
    StructField("Suffix", StringType(), True),
    StructField("CompanyName", StringType(), True),
    StructField("SalesPerson", StringType(), True),
    StructField("EmailAddress", StringType(), True),
    StructField("Phone", StringType(), True),
    StructField("PasswordHash", StringType(), False),
    StructField("PasswordSalt", StringType(), False),
    StructField("rowguid", StringType(), False),
    StructField("ModifiedDate", TimestampType(), False)
])

# %%
customer_data = [
    (1, False, "Mr.", "Orlando", "N.", "Gee", None, "A Bike Store", "adventure-works\pamela0", "orlando@example.com", "245-555-0173", "hash1", "salt1", "C1", datetime.datetime(2026,1,1)),
    (2, False, "Mr.", "Keith", None, "Harris", None, "Progressive Sports", "adventure-works\david8", "keith@example.com", "170-555-0127", "hash2", "salt2", "C2", datetime.datetime(2026,1,2)),
    (3, False, "Ms.", "Donna", "F.", "Carreras", None, "Advanced Bike Components", "adventure-works\jillian0", "donna@example.com", "279-555-0130", "hash3", "salt3", "C3", datetime.datetime(2026,1,3)),
    (4, False, "Mr.", "Janeth", None, "Esteves", None, "Modular Cycle Systems", "adventure-works\garrett1", "janeth@example.com", "710-555-0173", "hash4", "salt4", "C4", datetime.datetime(2026,1,4)),
    (5, False, "Ms.", "Lucy", None, "Harrington", None, "Metropolitan Sports", "adventure-works\jillian0", "lucy@example.com", "828-555-0188", "hash5", "salt5", "C5", datetime.datetime(2026,1,5))
]
df_customer = spark.createDataFrame(customer_data, customer_schema)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\p'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:4: SyntaxWarning: invalid escape sequence '\j'
# <>:5: SyntaxWarning: invalid escape sequence '\g'
# <>:6: SyntaxWarning: invalid escape sequence '\j'
# <>:2: SyntaxWarning: invalid escape sequence '\p'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:4: SyntaxWarning: invalid escape sequence '\j'
# <>:5: SyntaxWarning: invalid escape sequence '\g'
# <>:6: SyntaxWarning: invalid escape sequence '\j'
# /home/spark-0c86a1e2-4c05-4679-8a8f-97/.ipykernel/10552/command-4930614754957441-4152632148:2: SyntaxWarning: invalid escape sequence '\p'
#   (1, False, "Mr.", "Orlando", "N.", "Gee", None, "A Bike Store", "adventure-works\pamela0", "orlando@example.com", "245-555-0173", "hash1", "salt1", "C1", datetime.datetime(2026,1,1)),
# /home/spark-0c86a1e2-4c05-4679-8a8f-97/.ipykernel/10552/command-4930614754957441-4152632148:3: SyntaxWarning: invalid escape sequence '\d'
#   (2, False, "Mr.", "Keith", None, "Harris", None, "Progressive Sports", "adventure-works\david8", "keith@example.com", "170-555-0127", "hash2", "salt2", "C2", datetime.datetime(2026,1,2)),
# /home/spark-0c86a1e2-4c05-4679-8a8f-97/.ipykernel/10552/command-4930614754957441-4152632148:4: SyntaxWarning: invalid escape sequence '\j'
#   (3, False, "Ms.", "Donna", "F.", "Carreras", None, "Advanced Bike Components", "adventure-works\jillian0", "donna@example.com", "279-555-0130", "hash3", "salt3", "C3", datetime.datetime(2026,1,3)),
# /home/spark-0c86a1e2-4c05-4679-8a8f-97/.ipykernel/10552/command-4930614754957441-4152632148:5: SyntaxWarning: invalid escape sequence '\g'
#   (4, False, "Mr.", "Janeth", None, "Esteves", None, "Modular Cycle Systems", "adventure-works\garrett1", "janeth@example.com", "710-555-0173", "hash4", "salt4", "C4", datetime.datetime(2026,1,4)),
# /home/spark-0c86a1e2-4c05-4679-8a8f-97/.ipykernel/10552/command-4930614754957441-4152632148:6: SyntaxWarning: invalid escape sequence '\j'
#   (5, False, "Ms.", "Lucy", None, "Harrington", None, "Metropolitan Sports", "adventure-works\jillian0", "lucy@example.com", "828-555-0188", "hash5", "salt5", "C5", datetime.datetime(2026,1,5))
# <unknown>:2: SyntaxWarning: invalid escape sequence '\p'
# <unknown>:3: SyntaxWarning: invalid escape sequence '\d'
# <unknown>:4: SyntaxWarning: invalid escape sequence '\j'
# <unknown>:5: SyntaxWarning: invalid escape sequence '\g'
# <unknown>:6: SyntaxWarning: invalid escape sequence '\j'

# %%
# 3. Pack them into the tracking dictionary
# ==========================================
bronze_tables = {
    "address": df_address,
    "customer": df_customer
}

print("Source data and schemas mapped successfully.")
# Out:
# Source data and schemas mapped successfully.

# %%
# BRONZE LAYER
# Task 1
print("Data structures initialized.")
# Out:
# Data structures initialized.

# %%
# Tasks 2, 3, 4, 10
from pyspark.sql.functions import current_timestamp, lit

processed_bronze = {}
for table_name, df in bronze_tables.items():
    # Tasks 2, 3, 4: Metadata
    df_meta = df.withColumn("ingestion_timestamp", current_timestamp()) \
                .withColumn("source_system", lit("AzureSQL")) \
                .withColumn("source_table", lit(f"SalesLT.{table_name}"))
    
    # Task 10: Lowercase columns
    for col_name in df_meta.columns:
        df_meta = df_meta.withColumnRenamed(col_name, col_name.lower())
    
    processed_bronze[table_name] = df_meta
print("Tasks 2, 3, 4, 10 complete: Metadata added and columns lowercased.")
# Out:
# Tasks 2, 3, 4, 10 complete: Metadata added and columns lowercased.

# %%
# Task 11,12
# Task 11: Create Temp Views
for table_name, df in processed_bronze.items():
    df.createOrReplaceTempView(f"saleslt_{table_name}")

# Task 12: Read via Spark SQL
print("Task 12 Result:")
spark.sql("SELECT customerid, firstname FROM saleslt_customer LIMIT 2").show()
# Out:
# Task 12 Result:
# +----------+---------+
# |customerid|firstname|
# +----------+---------+
# |         1|  Orlando|
# |         2|    Keith|
# +----------+---------+

# %%
# Tasks 5, 6, 7
target_df = spark.table("saleslt_customer")
print("Task 5 (First 10):")
target_df.show(10)
print(f"Task 6 (Count): {target_df.count()}")
print("Task 7 (Schema):")
target_df.printSchema()
# Out:
# Task 5 (First 10):
# +----------+---------+-----+---------+----------+----------+------+--------------------+--------------------+-------------------+------------+------------+------------+-------+-------------------+--------------------+-------------+----------------+
# |customerid|namestyle|title|firstname|middlename|  lastname|suffix|         companyname|         salesperson|       emailaddress|       phone|passwordhash|passwordsalt|rowguid|       modifieddate| ingestion_timestamp|source_system|    source_table|
# +----------+---------+-----+---------+----------+----------+------+--------------------+--------------------+-------------------+------------+------------+------------+-------+-------------------+--------------------+-------------+----------------+
# |         1|    false|  Mr.|  Orlando|        N.|       Gee|  NULL|        A Bike Store|adventure-works\p...|orlando@example.com|245-555-0173|       hash1|       salt1|     C1|2026-01-01 00:00:00|2026-06-12 03:43:...|     AzureSQL|SalesLT.customer|
# |         2|    false|  Mr.|    Keith|      NULL|    Harris|  NULL|  Progressive Sports|adventure-works\d...|  keith@example.com|170-555-0127|       hash2|       salt2|     C2|2026-01-02 00:00:00|2026-06-12 03:43:...|     AzureSQL|SalesLT.customer|
# |         3|    false|  Ms.|    Donna|        F.|  Carreras|  NULL|Advanced Bike Com...|adventure-works\j...|  donna@example.com|279-555-0130|       hash3|       salt3|     C3|2026-01-03 00:00:00|2026-06-12 03:43:...|     AzureSQL|SalesLT.customer|
# |         4|    false|  Mr.|   Janeth|      NULL|   Esteves|  NULL|Modular Cycle Sys...|adventure-works\g...| janeth@example.com|710-555-0173|       hash4|       salt4|     C4|2026-01-04 00:00:00|2026-06-12 03:43:...|     AzureSQL|SalesLT.customer|
# |         5|    false|  Ms.|     Lucy|      NULL|Harrington|  NULL| Metropolitan Sports|adventure-works\j...|   lucy@example.com|828-555-0188|       hash5|       salt5|     C5|2026-01-05 00:00:00|2026-06-12 03:43:...|     AzureSQL|SalesLT.customer|
# +----------+---------+-----+---------+----------+----------+------+--------------------+--------------------+-------------------+------------+------------+------------+-------+-------------------+--------------------+-------------+----------------+
#
# Task 6 (Count): 5
# Task 7 (Schema):
# root
#  |-- customerid: integer (nullable = false)
#  |-- namestyle: boolean (nullable = false)
#  |-- title: string (nullable = true)
#  |-- firstname: string (nullable = false)
#  |-- middlename: string (nullable = true)
#  |-- lastname: string (nullable = false)
#  |-- suffix: string (nullable = true)
#  |-- companyname: string (nullable = true)
#  |-- salesperson: string (nullable = true)
#  |-- emailaddress: string (nullable = true)
#  |-- phone: string (nullable = true)
#  |-- passwordhash: string (nullable = false)
#  |-- passwordsalt: string (nullable = false)
#  |-- rowguid: string (nullable = false)
#  |-- modifieddate: timestamp (nullable = false)
#  |-- ingestion_timestamp: timestamp (nullable = false)
#  |-- source_system: string (nullable = false)
#  |-- source_table: string (nullable = false)

# %%
# Task 19, 20
import datetime
from pyspark.sql.types import StructType, StructField, StringType, LongType, TimestampType

audit_records = [(f"SalesLT.{name}", df.count(), "SUCCESS", datetime.datetime.now()) for name, df in processed_bronze.items()]
df_audit = spark.createDataFrame(audit_records, ["table_name", "row_count", "load_status", "execution_timestamp"])

print("Tasks 19 & 20 Audit Log:")
df_audit.show(truncate=False)
# Out:
# Tasks 19 & 20 Audit Log:
# +----------------+---------+-----------+--------------------------+
# |table_name      |row_count|load_status|execution_timestamp       |
# +----------------+---------+-----------+--------------------------+
# |SalesLT.address |5        |SUCCESS    |2026-06-12 03:44:17.078288|
# |SalesLT.customer|5        |SUCCESS    |2026-06-12 03:44:17.742723|
# +----------------+---------+-----------+--------------------------+

# %%
# Task 15
table_name = "customer"
processed_bronze[table_name] = processed_bronze[table_name].repartition(4)

print(f"Table '{table_name}' has been repartitioned to 4.")
# Out:
# Table 'customer' has been repartitioned to 4.

# %%
# 10
for col_name in df.columns:
    df = df.withColumnRenamed(col_name, col_name.lower())
print(df.columns)
df.show(10, truncate=False)
# Out:
# ['customerid', 'namestyle', 'title', 'firstname', 'middlename', 'lastname', 'suffix', 'companyname', 'salesperson', 'emailaddress', 'phone', 'passwordhash', 'passwordsalt', 'rowguid', 'modifieddate', 'ingestion_timestamp', 'source_system', 'source_table']
# +----------+---------+-----+---------+----------+----------+------+------------------------+------------------------+-------------------+------------+------------+------------+-------+-------------------+-------------------------+-------------+----------------+
# |customerid|namestyle|title|firstname|middlename|lastname  |suffix|companyname             |salesperson             |emailaddress       |phone       |passwordhash|passwordsalt|rowguid|modifieddate       |ingestion_timestamp      |source_system|source_table    |
# +----------+---------+-----+---------+----------+----------+------+------------------------+------------------------+-------------------+------------+------------+------------+-------+-------------------+-------------------------+-------------+----------------+
# |1         |false    |Mr.  |Orlando  |N.        |Gee       |NULL  |A Bike Store            |adventure-works\pamela0 |orlando@example.com|245-555-0173|hash1       |salt1       |C1     |2026-01-01 00:00:00|2026-06-12 03:46:00.22085|AzureSQL     |SalesLT.customer|
# |2         |false    |Mr.  |Keith    |NULL      |Harris    |NULL  |Progressive Sports      |adventure-works\david8  |keith@example.com  |170-555-0127|hash2       |salt2       |C2     |2026-01-02 00:00:00|2026-06-12 03:46:00.22085|AzureSQL     |SalesLT.customer|
# |3         |false    |Ms.  |Donna    |F.        |Carreras  |NULL  |Advanced Bike Components|adventure-works\jillian0|donna@example.com  |279-555-0130|hash3       |salt3       |C3     |2026-01-03 00:00:00|2026-06-12 03:46:00.22085|AzureSQL     |SalesLT.customer|
# |4         |false    |Mr.  |Janeth   |NULL      |Esteves   |NULL  |Modular Cycle Systems   |adventure-works\garrett1|janeth@example.com |710-555-0173|hash4       |salt4       |C4     |2026-01-04 00:00:00|2026-06-12 03:46:00.22085|AzureSQL     |SalesLT.customer|
# |5         |false    |Ms.  |Lucy     |NULL      |Harrington|NULL  |Metropolitan Sports     |adventure-works\jillian0|lucy@example.com   |828-555-0188|hash5       |salt5       |C5     |2026-01-05 00:00:00|2026-06-12 03:46:00.22085|AzureSQL     |SalesLT.customer|
# +----------+---------+-----+---------+----------+----------+------+------------------------+------------------------+-------------------+------------+------------+------------+-------+-------------------+-------------------------+-------------+----------------+

# %%
# SILVER LAYER
# 1
for name, df in processed_bronze.items():
    processed_silver = df.dropDuplicates()
    print(f"Task 1: Duplicates removed from {name}.")
# Out:
# Task 1: Duplicates removed from address.
# Task 1: Duplicates removed from customer.

# %%
# Task 3 & 4
from pyspark.sql.functions import to_date, to_timestamp
df = df.withColumn("modified_date", to_date("modifieddate")) \
       .withColumn("ingestion_timestamp", to_timestamp("ingestion_timestamp"))
print("Task 3/4: Date/Timestamp formats applied.")
# Out:
# Task 3/4: Date/Timestamp formats applied.

# %%
# Task 5 & 6
from pyspark.sql.functions import trim, col
df = df.fillna({"firstname": "N/A", "lastname": "N/A"})
string_cols = [c for c, t in df.dtypes if t == 'string']
df = df.select([trim(col(c)).alias(c) if c in string_cols else col(c) for c in df.columns])
print("Task 5/6: Nulls filled and strings trimmed.")
df.select("firstname", "lastname", "emailaddress").show(5)
# Out:
# Task 5/6: Nulls filled and strings trimmed.
# +---------+----------+-------------------+
# |firstname|  lastname|       emailaddress|
# +---------+----------+-------------------+
# |    Donna|  Carreras|  donna@example.com|
# |  Orlando|       Gee|orlando@example.com|
# |    Keith|    Harris|  keith@example.com|
# |   Janeth|   Esteves| janeth@example.com|
# |     Lucy|Harrington|   lucy@example.com|
# +---------+----------+-------------------+

# %%
# Task 7 & 8
from pyspark.sql.functions import col, lower, concat_ws
df_silver = df.withColumn("email_address", lower(col("emailaddress"))) \
              .withColumn("full_name", concat_ws(" ", col("firstname"), col("lastname")))
df_silver.select("customerid", "firstname", "lastname", "full_name", "email_address").show(truncate=False)
# Out:
# +----------+---------+----------+---------------+-------------------+
# |customerid|firstname|lastname  |full_name      |email_address      |
# +----------+---------+----------+---------------+-------------------+
# |3         |Donna    |Carreras  |Donna Carreras |donna@example.com  |
# |1         |Orlando  |Gee       |Orlando Gee    |orlando@example.com|
# |2         |Keith    |Harris    |Keith Harris   |keith@example.com  |
# |4         |Janeth   |Esteves   |Janeth Esteves |janeth@example.com |
# |5         |Lucy     |Harrington|Lucy Harrington|lucy@example.com   |
# +----------+---------+----------+---------------+-------------------+

# %%
# 9,10,11
# %whos
# Out:
# Variable                           Type                 Data/Info
# -----------------------------------------------------------------
# AnalyzeArgument                    type                 <class 'pyspark.sql.udtf.AnalyzeArgument'>
# AnalyzeResult                      type                 <class 'pyspark.sql.udtf.AnalyzeResult'>
# ArrayType                          type                 <class 'pyspark.sql.types.ArrayType'>
# ArrowUDFType                       type                 <class 'pyspark.sql.panda<...>.functions.ArrowUDFType'>
# BinaryType                         DataTypeSingleton    <class 'pyspark.sql.types.BinaryType'>
# BooleanType                        DataTypeSingleton    <class 'pyspark.sql.types.BooleanType'>
# ByteType                           DataTypeSingleton    <class 'pyspark.sql.types.ByteType'>
# CalendarIntervalType               DataTypeSingleton    <class 'pyspark.sql.types.CalendarIntervalType'>
# CharType                           type                 <class 'pyspark.sql.types.CharType'>
# Column                             type                 <class 'pyspark.sql.column.Column'>
# DataFrame                          type                 <class 'pyspark.sql.dataframe.DataFrame'>
# DataType                           type                 <class 'pyspark.sql.types.DataType'>
# DateType                           DataTypeSingleton    <class 'pyspark.sql.types.DateType'>
# DayTimeIntervalType                type                 <class 'pyspark.sql.types.DayTimeIntervalType'>
# Decimal                            type                 <class 'decimal.Decimal'>
# DecimalType                        type                 <class 'pyspark.sql.types.DecimalType'>
# DoubleType                         DataTypeSingleton    <class 'pyspark.sql.types.DoubleType'>
# FloatType                          DataTypeSingleton    <class 'pyspark.sql.types.FloatType'>
# Geography                          type                 <class 'pyspark.sql.types.Geography'>
# GeographyType                      type                 <class 'pyspark.sql.types.GeographyType'>
# Geometry                           type                 <class 'pyspark.sql.types.Geometry'>
# GeometryType                       type                 <class 'pyspark.sql.types.GeometryType'>
# IntegerType                        DataTypeSingleton    <class 'pyspark.sql.types.IntegerType'>
# LongType                           DataTypeSingleton    <class 'pyspark.sql.types.LongType'>
# MapType                            type                 <class 'pyspark.sql.types.MapType'>
# NullType                           DataTypeSingleton    <class 'pyspark.sql.types.NullType'>
# OrderingColumn                     type                 <class 'pyspark.sql.udtf.OrderingColumn'>
# PandasUDFType                      type                 <class 'pyspark.sql.panda<...>functions.PandasUDFType'>
# PartitioningColumn                 type                 <class 'pyspark.sql.udtf.PartitioningColumn'>
# Row                                type                 <class 'pyspark.sql.types.Row'>
# SelectedColumn                     type                 <class 'pyspark.sql.udtf.SelectedColumn'>
# ShortType                          DataTypeSingleton    <class 'pyspark.sql.types.ShortType'>
# SkipRestOfInputTableException      type                 <class 'pyspark.sql.udtf.<...>stOfInputTableException'>
# StringType                         type                 <class 'pyspark.sql.types.StringType'>
# StructField                        type                 <class 'pyspark.sql.types.StructField'>
# StructType                         type                 <class 'pyspark.sql.types.StructType'>
# TimeType                           type                 <class 'pyspark.sql.types.TimeType'>
# TimestampNTZType                   DataTypeSingleton    <class 'pyspark.sql.types.TimestampNTZType'>
# TimestampType                      DataTypeSingleton    <class 'pyspark.sql.types.TimestampType'>
# UserDefinedFunction                type                 <class 'pyspark.sql.udf.UserDefinedFunction'>
# UserDefinedTableFunction           type                 <class 'pyspark.sql.udtf.<...>serDefinedTableFunction'>
# VarcharType                        type                 <class 'pyspark.sql.types.VarcharType'>
# VariantType                        type                 <class 'pyspark.sql.types.VariantType'>
# VariantVal                         type                 <class 'pyspark.sql.types.VariantVal'>
# YearMonthIntervalType              type                 <class 'pyspark.sql.types.YearMonthIntervalType'>
# abs                                function             <function abs at 0xfff5831fe5c0>
# acos                               function             <function acos at 0xfff5831ffc40>
# acosh                              function             <function acosh at 0xfff5831ffd80>
# add_months                         function             <function add_months at 0xfff583221260>
# address_data                       list                 n=5
# address_schema                     StructType           StructType([StructField('<...>TimestampType(), False)])
# aes_decrypt                        function             <function aes_decrypt at 0xfff5832694e0>
# aes_encrypt                        function             <function aes_encrypt at 0xfff5832693a0>
# aggregate                          function             <function aggregate at 0xfff583253100>
# ai_parse_document                  function             <function ai_parse_document at 0xfff583247420>
# any_value                          function             <function any_value at 0xfff58321a0c0>
# approxCountDistinct                function             <function approxCountDistinct at 0xfff583212340>
# approx_count_distinct              function             <function approx_count_di<...>stinct at 0xfff583212480>
# approx_percentile                  function             <function approx_percentile at 0xfff583213d80>
# array                              function             <function array at 0xfff583245120>
# array_agg                          function             <function array_agg at 0xfff5832111c0>
# array_append                       function             <function array_append at 0xfff5832467a0>
# array_compact                      function             <function array_compact at 0xfff583246660>
# array_contains                     function             <function array_contains at 0xfff583245260>
# array_distinct                     function             <function array_distinct at 0xfff583246020>
# array_except                       function             <function array_except at 0xfff583246520>
# array_insert                       function             <function array_insert at 0xfff583246160>
# array_intersect                    function             <function array_intersect at 0xfff5832462a0>
# array_join                         function             <function array_join at 0xfff583245620>
# array_max                          function             <function array_max at 0xfff583250d60>
# array_min                          function             <function array_min at 0xfff583250c20>
# array_position                     function             <function array_position at 0xfff5832458a0>
# array_prepend                      function             <function array_prepend at 0xfff583245da0>
# array_remove                       function             <function array_remove at 0xfff583245ee0>
# array_repeat                       function             <function array_repeat at 0xfff583251da0>
# array_size                         function             <function array_size at 0xfff583250ea0>
# array_sort                         function             <function array_sort at 0xfff583251260>
# array_union                        function             <function array_union at 0xfff5832463e0>
# arrays_overlap                     function             <function arrays_overlap at 0xfff5832453a0>
# arrays_zip                         function             <function arrays_zip at 0xfff583251ee0>
# arrow_udf                          function             <function arrow_udf at 0xfff5831fc720>
# arrow_udtf                         function             <function arrow_udtf at 0xfff58326b2e0>
# asc                                function             <function asc at 0xfff5831fd940>
# asc_nulls_first                    function             <function asc_nulls_first at 0xfff583206c00>
# asc_nulls_last                     function             <function asc_nulls_last at 0xfff583206d40>
# ascii                              function             <function ascii at 0xfff58322e3e0>
# asin                               function             <function asin at 0xfff5831ffec0>
# asinh                              function             <function asinh at 0xfff583204040>
# assert_true                        function             <function assert_true at 0xfff58322dee0>
# atan                               function             <function atan at 0xfff583204180>
# atan2                              function             <function atan2 at 0xfff583211760>
# atanh                              function             <function atanh at 0xfff5832042c0>
# audit_records                      list                 n=2
# avg                                function             <function avg at 0xfff5831fefc0>
# base64                             function             <function base64 at 0xfff58322e520>
# bin                                function             <function bin at 0xfff5832393a0>
# bit_and                            function             <function bit_and at 0xfff583210a40>
# bit_count                          function             <function bit_count at 0xfff583206840>
# bit_get                            function             <function bit_get at 0xfff583206980>
# bit_length                         function             <function bit_length at 0xfff583239b20>
# bit_or                             function             <function bit_or at 0xfff583210b80>
# bit_xor                            function             <function bit_xor at 0xfff583210cc0>
# bitmap_and_agg                     function             <function bitmap_and_agg at 0xfff58326a8e0>
# bitmap_bit_position                function             <function bitmap_bit_position at 0xfff58326a2a0>
# bitmap_bucket_number               function             <function bitmap_bucket_number at 0xfff58326a3e0>
# bitmap_construct_agg               function             <function bitmap_construct_agg at 0xfff58326a520>
# bitmap_count                       function             <function bitmap_count at 0xfff58326a660>
# bitmap_or_agg                      function             <function bitmap_or_agg at 0xfff58326a7a0>
# bitwiseNOT                         function             <function bitwiseNOT at 0xfff5832065c0>
# bitwise_not                        function             <function bitwise_not at 0xfff583206700>
# bool_and                           function             <function bool_and at 0xfff583210680>
# bool_or                            function             <function bool_or at 0xfff583210900>
# broadcast                          function             <function broadcast at 0xfff5832125c0>
# bronze_tables                      dict                 n=2
# bround                             function             <function bround at 0xfff5832182c0>
# btrim                              function             <function btrim at 0xfff58323b2e0>
# bucket                             function             <function bucket at 0xfff583261bc0>
# call_function                      function             <function call_function at 0xfff583261e40>
# call_udf                           function             <function call_udf at 0xfff583261d00>
# cardinality                        function             <function cardinality at 0xfff583250fe0>
# cbrt                               function             <function cbrt at 0xfff583204400>
# ceil                               function             <function ceil at 0xfff583204540>
# ceiling                            function             <function ceiling at 0xfff583204680>
# char                               function             <function char at 0xfff58323b1a0>
# char_length                        function             <function char_length at 0xfff58323b420>
# character_length                   function             <function character_length at 0xfff58323b560>
# coalesce                           function             <function coalesce at 0xfff583212700>
# col                                function             <function col at 0xfff5831fd800>
# col_name                           str                  source_table
# collate                            function             <function collate at 0xfff583244720>
# collation                          function             <function collation at 0xfff583244860>
# collect_list                       function             <function collect_list at 0xfff583211080>
# collect_set                        function             <function collect_set at 0xfff583211300>
# column                             function             <function col at 0xfff5831fd800>
# concat                             function             <function concat at 0xfff583245760>
# concat_ws                          function             <function concat_ws at 0xfff58322eb60>
# contains                           function             <function contains at 0xfff58323ba60>
# conv                               function             <function conv at 0xfff583219a80>
# convert_timezone                   function             <function convert_timezone at 0xfff583260040>
# corr                               function             <function corr at 0xfff583212840>
# cos                                function             <function cos at 0xfff5832047c0>
# cosh                               function             <function cosh at 0xfff583204900>
# cot                                function             <function cot at 0xfff583204a40>
# count                              function             <function count at 0xfff5831fed40>
# countDistinct                      function             <function countDistinct at 0xfff583212c00>
# count_distinct                     function             <function count_distinct at 0xfff583212d40>
# count_if                           function             <function count_if at 0xfff58321a480>
# count_min_sketch                   function             <function count_min_sketch at 0xfff583213240>
# covar_pop                          function             <function covar_pop at 0xfff583212980>
# covar_samp                         function             <function covar_samp at 0xfff583212ac0>
# crc32                              function             <function crc32 at 0xfff58322d760>
# create_map                         function             <function create_map at 0xfff583244cc0>
# csc                                function             <function csc at 0xfff583204b80>
# cume_dist                          function             <function cume_dist at 0xfff5832120c0>
# curdate                            function             <function curdate at 0xfff58321a840>
# current_catalog                    function             <function current_catalog at 0xfff58322cea0>
# current_database                   function             <function current_database at 0xfff58322cfe0>
# current_date                       function             <function current_date at 0xfff58321a980>
# current_schema                     function             <function current_schema at 0xfff58322d120>
# current_time                       function             <function current_time at 0xfff58321ade0>
# current_timestamp                  function             <function current_timestamp at 0xfff58321af20>
# current_timezone                   function             <function current_timezone at 0xfff58321aac0>
# current_user                       function             <function current_user at 0xfff58322d260>
# customer_address_data              list                 n=5
# customer_address_schema            StructType           StructType([StructField('<...>TimestampType(), False)])
# customer_data                      list                 n=5
# customer_schema                    StructType           StructType([StructField('<...>TimestampType(), False)])
# date_add                           function             <function date_add at 0xfff583220ae0>
# date_diff                          function             <function date_diff at 0xfff583220fe0>
# date_format                        function             <function date_format at 0xfff58321b2e0>
# date_from_unix_date                function             <function date_from_unix_date at 0xfff583221120>
# date_part                          function             <function date_part at 0xfff583220720>
# date_sub                           function             <function date_sub at 0xfff583220d60>
# date_trunc                         function             <function date_trunc at 0xfff583223380>
# dateadd                            function             <function dateadd at 0xfff583220c20>
# datediff                           function             <function datediff at 0xfff583220ea0>
# datepart                           function             <function datepart at 0xfff583220860>
# datetime                           module               <module 'datetime' from '<...>/python3.12/datetime.py'>
# day                                function             <function day at 0xfff58321ba60>
# dayname                            function             <function dayname at 0xfff5832204a0>
# dayofmonth                         function             <function dayofmonth at 0xfff58321b920>
# dayofweek                          function             <function dayofweek at 0xfff58321b7e0>
# dayofyear                          function             <function dayofyear at 0xfff58321bba0>
# days                               function             <function days at 0xfff583253d80>
# decode                             function             <function decode at 0xfff58322eca0>
# degrees                            function             <function degrees at 0xfff583211440>
# dense_rank                         function             <function dense_rank at 0xfff583211e40>
# desc                               function             <function desc at 0xfff5831fda80>
# desc_nulls_first                   function             <function desc_nulls_first at 0xfff583206e80>
# desc_nulls_last                    function             <function desc_nulls_last at 0xfff583206fc0>
# df                                 DataFrame            DataFrame[customerid: int<...>ing, modified_date: date]
# df_address                         DataFrame            DataFrame[AddressID: int,<...> ModifiedDate: timestamp]
# df_audit                           DataFrame            DataFrame[table_name: str<...>ion_timestamp: timestamp]
# df_customer                        DataFrame            DataFrame[CustomerID: int<...> ModifiedDate: timestamp]
# df_customer_address                DataFrame            DataFrame[CustomerID: int<...> ModifiedDate: timestamp]
# df_meta                            DataFrame            DataFrame[customerid: int<...>ng, source_table: string]
# df_product                         DataFrame            DataFrame[ProductID: int,<...> ModifiedDate: timestamp]
# df_product_category                DataFrame            DataFrame[ProductCategory<...> ModifiedDate: timestamp]
# df_product_description             DataFrame            DataFrame[ProductDescript<...> ModifiedDate: timestamp]
# df_product_model                   DataFrame            DataFrame[ProductModelID:<...> ModifiedDate: timestamp]
# df_product_model_description       DataFrame            DataFrame[ProductModelID:<...> ModifiedDate: timestamp]
# df_sales_order_detail              DataFrame            DataFrame[SalesOrderID: i<...> ModifiedDate: timestamp]
# df_sales_order_header              DataFrame            DataFrame[SalesOrderID: i<...> ModifiedDate: timestamp]
# df_silver                          DataFrame            DataFrame[customerid: int<...>tring, full_name: string]
# e                                  function             <function e at 0xfff583204cc0>
# element_at                         function             <function element_at at 0xfff5832459e0>
# elt                                function             <function elt at 0xfff58323bba0>
# encode                             function             <function encode at 0xfff58322ede0>
# endswith                           function             <function endswith at 0xfff58323af20>
# equal_null                         function             <function equal_null at 0xfff583268b80>
# every                              function             <function every at 0xfff583210540>
# exists                             function             <function exists at 0xfff583252b60>
# exp                                function             <function exp at 0xfff583204e00>
# explode                            function             <function explode at 0xfff5832468e0>
# explode_outer                      function             <function explode_outer at 0xfff583246ca0>
# expm1                              function             <function expm1 at 0xfff583204f40>
# expr                               function             <function expr at 0xfff583218cc0>
# extract                            function             <function extract at 0xfff5832205e0>
# factorial                          function             <function factorial at 0xfff583219bc0>
# filter                             function             <function filter at 0xfff583252fc0>
# find_in_set                        function             <function find_in_set at 0xfff58323bce0>
# first                              function             <function first at 0xfff583212e80>
# first_value                        function             <function first_value at 0xfff58321a200>
# flatten                            function             <function flatten at 0xfff583251620>
# floor                              function             <function floor at 0xfff583205080>
# forall                             function             <function forall at 0xfff583252ca0>
# format_number                      function             <function format_number at 0xfff58322f420>
# format_string                      function             <function format_string at 0xfff58322f560>
# from_csv                           function             <function from_csv at 0xfff583252480>
# from_json                          function             <function from_json at 0xfff5832472e0>
# from_unixtime                      function             <function from_unixtime at 0xfff583223740>
# from_utc_timestamp                 function             <function from_utc_timestamp at 0xfff583223ba0>
# from_xml                           function             <function from_xml at 0xfff5832504a0>
# get                                function             <function get at 0xfff583245c60>
# get_json_object                    function             <function get_json_object at 0xfff583247060>
# getbit                             function             <function getbit at 0xfff583206ac0>
# greatest                           function             <function greatest at 0xfff583219260>
# grouping                           function             <function grouping at 0xfff583212fc0>
# grouping_id                        function             <function grouping_id at 0xfff583213100>
# hash                               function             <function hash at 0xfff58322dc60>
# hex                                function             <function hex at 0xfff5832394e0>
# histogram_numeric                  function             <function histogram_numeric at 0xfff58321a5c0>
# hll_sketch_agg                     function             <function hll_sketch_agg at 0xfff5832620c0>
# hll_sketch_estimate                function             <function hll_sketch_estimate at 0xfff583262340>
# hll_union                          function             <function hll_union at 0xfff583262480>
# hll_union_agg                      function             <function hll_union_agg at 0xfff583262200>
# hour                               function             <function hour at 0xfff58321bce0>
# hours                              function             <function hours at 0xfff583253ec0>
# hypot                              function             <function hypot at 0xfff583211800>
# ifnull                             function             <function ifnull at 0xfff583268900>
# ilike                              function             <function ilike at 0xfff58323bf60>
# initcap                            function             <function initcap at 0xfff583239120>
# inline                             function             <function inline at 0xfff583246b60>
# inline_outer                       function             <function inline_outer at 0xfff583246f20>
# input_file_block_length            function             <function input_file_bloc<...>length at 0xfff5832698a0>
# input_file_block_start             function             <function input_file_bloc<...>_start at 0xfff5832699e0>
# input_file_name                    function             <function input_file_name at 0xfff583213380>
# instr                              function             <function instr at 0xfff58322f6a0>
# is_valid_utf8                      function             <function is_valid_utf8 at 0xfff58322ef20>
# is_variant_null                    function             <function is_variant_null at 0xfff583247920>
# isnan                              function             <function isnan at 0xfff5832134c0>
# isnotnull                          function             <function isnotnull at 0xfff583268a40>
# isnull                             function             <function isnull at 0xfff583213600>
# java_method                        function             <function java_method at 0xfff583269c60>
# json_array_length                  function             <function json_array_length at 0xfff583250220>
# json_object_keys                   function             <function json_object_keys at 0xfff583250360>
# json_tuple                         function             <function json_tuple at 0xfff5832471a0>
# kll_merge_agg_bigint               function             <function kll_merge_agg_bigint at 0xfff583262d40>
# kll_merge_agg_double               function             <function kll_merge_agg_double at 0xfff583262fc0>
# kll_merge_agg_float                function             <function kll_merge_agg_float at 0xfff583262e80>
# kll_sketch_agg_bigint              function             <function kll_sketch_agg_<...>bigint at 0xfff583262980>
# kll_sketch_agg_double              function             <function kll_sketch_agg_<...>double at 0xfff583262c00>
# kll_sketch_agg_float               function             <function kll_sketch_agg_float at 0xfff583262ac0>
# kll_sketch_get_n_bigint            function             <function kll_sketch_get_<...>bigint at 0xfff5832634c0>
# kll_sketch_get_n_double            function             <function kll_sketch_get_<...>double at 0xfff583263740>
# kll_sketch_get_n_float             function             <function kll_sketch_get_<...>_float at 0xfff583263600>
# kll_sketch_get_quantile_bigint     function             <function kll_sketch_get_<...>bigint at 0xfff583263c40>
# kll_sketch_get_quantile_double     function             <function kll_sketch_get_<...>double at 0xfff583263ec0>
# kll_sketch_get_quantile_float      function             <function kll_sketch_get_<...>_float at 0xfff583263d80>
# kll_sketch_get_rank_bigint         function             <function kll_sketch_get_<...>bigint at 0xfff583268040>
# kll_sketch_get_rank_double         function             <function kll_sketch_get_<...>double at 0xfff5832682c0>
# kll_sketch_get_rank_float          function             <function kll_sketch_get_<...>_float at 0xfff583268180>
# kll_sketch_merge_bigint            function             <function kll_sketch_merg<...>bigint at 0xfff583263880>
# kll_sketch_merge_double            function             <function kll_sketch_merg<...>double at 0xfff583263b00>
# kll_sketch_merge_float             function             <function kll_sketch_merg<...>_float at 0xfff5832639c0>
# kll_sketch_to_string_bigint        function             <function kll_sketch_to_s<...>bigint at 0xfff583263100>
# kll_sketch_to_string_double        function             <function kll_sketch_to_s<...>double at 0xfff583263380>
# kll_sketch_to_string_float         function             <function kll_sketch_to_s<...>_float at 0xfff583263240>
# kurtosis                           function             <function kurtosis at 0xfff583210f40>
# lag                                function             <function lag at 0xfff583219d00>
# last                               function             <function last at 0xfff583213740>
# last_day                           function             <function last_day at 0xfff583223600>
# last_value                         function             <function last_value at 0xfff58321a340>
# lcase                              function             <function lcase at 0xfff5832440e0>
# lead                               function             <function lead at 0xfff583219e40>
# least                              function             <function least at 0xfff5832193a0>
# left                               function             <function left at 0xfff583244360>
# length                             function             <function length at 0xfff5832398a0>
# levenshtein                        function             <function levenshtein at 0xfff58322fce0>
# like                               function             <function like at 0xfff58323bd80>
# listagg                            function             <function listagg at 0xfff5831ff600>
# listagg_distinct                   function             <function listagg_distinct at 0xfff5831ff740>
# lit                                function             <function lit at 0xfff5831fd620>
# ln                                 function             <function ln at 0xfff583219800>
# localtimestamp                     function             <function localtimestamp at 0xfff58321b1a0>
# locate                             function             <function locate at 0xfff58322fe20>
# log                                function             <function log at 0xfff5832196c0>
# log10                              function             <function log10 at 0xfff583205300>
# log1p                              function             <function log1p at 0xfff583205440>
# log2                               function             <function log2 at 0xfff583219940>
# lower                              function             <function lower at 0xfff58322e2a0>
# lpad                               function             <function lpad at 0xfff58322ff60>
# ltrim                              function             <function ltrim at 0xfff58322e7a0>
# make_date                          function             <function make_date at 0xfff5832209a0>
# make_dt_interval                   function             <function make_dt_interval at 0xfff583260180>
# make_interval                      function             <function make_interval at 0xfff583260400>
# make_time                          function             <function make_time at 0xfff583260540>
# make_timestamp                     function             <function make_timestamp at 0xfff583260a40>
# make_timestamp_ltz                 function             <function make_timestamp_ltz at 0xfff583261080>
# make_timestamp_ntz                 function             <function make_timestamp_ntz at 0xfff583261580>
# make_valid_utf8                    function             <function make_valid_utf8 at 0xfff58322f060>
# make_ym_interval                   function             <function make_ym_interval at 0xfff583261a80>
# map_concat                         function             <function map_concat at 0xfff583252200>
# map_contains_key                   function             <function map_contains_key at 0xfff583251760>
# map_entries                        function             <function map_entries at 0xfff583251b20>
# map_filter                         function             <function map_filter at 0xfff583253740>
# map_from_arrays                    function             <function map_from_arrays at 0xfff583244e00>
# map_from_entries                   function             <function map_from_entries at 0xfff583251c60>
# map_keys                           function             <function map_keys at 0xfff5832518a0>
# map_values                         function             <function map_values at 0xfff5832519e0>
# map_zip_with                       function             <function map_zip_with at 0xfff583253880>
# mask                               function             <function mask at 0xfff5832445e0>
# max                                function             <function max at 0xfff5831fe840>
# max_by                             function             <function max_by at 0xfff5831feac0>
# md5                                function             <function md5 at 0xfff58322d8a0>
# mean                               function             <function mean at 0xfff5831ff100>
# median                             function             <function median at 0xfff5831ff240>
# min                                function             <function min at 0xfff5831fe980>
# min_by                             function             <function min_by at 0xfff5831fec00>
# minute                             function             <function minute at 0xfff58321be20>
# mode                               function             <function mode at 0xfff5831fe700>
# monotonically_increasing_id        function             <function monotonically_i<...>ing_id at 0xfff583213880>
# month                              function             <function month at 0xfff58321b6a0>
# monthname                          function             <function monthname at 0xfff583220360>
# months                             function             <function months at 0xfff583253c40>
# months_between                     function             <function months_between at 0xfff5832213a0>
# name                               str                  customer
# named_struct                       function             <function named_struct at 0xfff583219120>
# nanvl                              function             <function nanvl at 0xfff5832139c0>
# negate                             function             <function negative at 0xfff583205580>
# negative                           function             <function negative at 0xfff583205580>
# next_day                           function             <function next_day at 0xfff5832234c0>
# now                                function             <function now at 0xfff58321b060>
# nth_value                          function             <function nth_value at 0xfff583219f80>
# ntile                              function             <function ntile at 0xfff58321a700>
# nullif                             function             <function nullif at 0xfff583268cc0>
# nullifzero                         function             <function nullifzero at 0xfff583268e00>
# nvl                                function             <function nvl at 0xfff583268f40>
# nvl2                               function             <function nvl2 at 0xfff583269080>
# octet_length                       function             <function octet_length at 0xfff5832399e0>
# overlay                            function             <function overlay at 0xfff58322f7e0>
# pandas_udf                         function             <function pandas_udf at 0xfff5831fc900>
# parse_json                         function             <function parse_json at 0xfff5832477e0>
# parse_url                          function             <function parse_url at 0xfff58323a7a0>
# percent_rank                       function             <function percent_rank at 0xfff583212200>
# percentile                         function             <function percentile at 0xfff583213b00>
# percentile_approx                  function             <function percentile_approx at 0xfff583213c40>
# pi                                 function             <function pi at 0xfff5832056c0>
# pmod                               function             <function pmod at 0xfff583211a80>
# posexplode                         function             <function posexplode at 0xfff583246a20>
# posexplode_outer                   function             <function posexplode_outer at 0xfff583246de0>
# position                           function             <function position at 0xfff58323ade0>
# positive                           function             <function positive at 0xfff583205800>
# pow                                function             <function pow at 0xfff583211940>
# power                              function             <function pow at 0xfff583211940>
# printf                             function             <function printf at 0xfff58323a8e0>
# processed_bronze                   dict                 n=2
# processed_silver                   DataFrame            DataFrame[customerid: int<...>ng, source_table: string]
# product                            function             <function product at 0xfff5831ffb00>
# product_category_data              list                 n=5
# product_category_schema            StructType           StructType([StructField('<...>TimestampType(), False)])
# product_data                       list                 n=5
# product_description_data           list                 n=5
# product_description_schema         StructType           StructType([StructField('<...>TimestampType(), False)])
# product_model_data                 list                 n=5
# product_model_description_data     list                 n=5
# product_model_description_schema   StructType           StructType([StructField('<...>TimestampType(), False)])
# product_model_schema               StructType           StructType([StructField('<...>TimestampType(), False)])
# product_schema                     StructType           StructType([StructField('<...>TimestampType(), False)])
# quarter                            function             <function quarter at 0xfff58321b560>
# quote                              function             <function quote at 0xfff5832449a0>
# radians                            function             <function radians at 0xfff583211580>
# raise_error                        function             <function raise_error at 0xfff58322e020>
# rand                               function             <function rand at 0xfff583213ec0>
# randn                              function             <function randn at 0xfff583218040>
# randstr                            function             <function randstr at 0xfff583238860>
# rank                               function             <function rank at 0xfff583211f80>
# reduce                             function             <function reduce at 0xfff583253240>
# reflect                            function             <function reflect at 0xfff583269b20>
# regexp                             function             <function regexp at 0xfff5832385e0>
# regexp_count                       function             <function regexp_count at 0xfff5832389a0>
# regexp_extract                     function             <function regexp_extract at 0xfff583238ae0>
# regexp_extract_all                 function             <function regexp_extract_all at 0xfff583238c20>
# regexp_instr                       function             <function regexp_instr at 0xfff583238fe0>
# regexp_like                        function             <function regexp_like at 0xfff583238720>
# regexp_replace                     function             <function regexp_replace at 0xfff583238d60>
# regexp_substr                      function             <function regexp_substr at 0xfff583238ea0>
# regr_avgx                          function             <function regr_avgx at 0xfff5832079c0>
# regr_avgy                          function             <function regr_avgy at 0xfff583207b00>
# regr_count                         function             <function regr_count at 0xfff583207c40>
# regr_intercept                     function             <function regr_intercept at 0xfff583207d80>
# regr_r2                            function             <function regr_r2 at 0xfff583207ec0>
# regr_slope                         function             <function regr_slope at 0xfff583210040>
# regr_sxx                           function             <function regr_sxx at 0xfff583210180>
# regr_sxy                           function             <function regr_sxy at 0xfff5832102c0>
# regr_syy                           function             <function regr_syy at 0xfff583210400>
# repeat                             function             <function repeat at 0xfff583238220>
# replace                            function             <function replace at 0xfff58323a2a0>
# reverse                            function             <function reverse at 0xfff5832514e0>
# right                              function             <function right at 0xfff5832444a0>
# rint                               function             <function rint at 0xfff583205940>
# rlike                              function             <function rlike at 0xfff5832384a0>
# round                              function             <function round at 0xfff583218180>
# row_number                         function             <function row_number at 0xfff583211d00>
# rpad                               function             <function rpad at 0xfff5832380e0>
# rtrim                              function             <function rtrim at 0xfff58322e8e0>
# sales_order_detail_data            list                 n=5
# sales_order_detail_schema          StructType           StructType([StructField('<...>TimestampType(), False)])
# sales_order_header_data            list                 n=3
# sales_order_header_schema          StructType           StructType([StructField('<...>TimestampType(), False)])
# schema_of_csv                      function             <function schema_of_csv at 0xfff583250860>
# schema_of_json                     function             <function schema_of_json at 0xfff5832500e0>
# schema_of_variant                  function             <function schema_of_variant at 0xfff583247ce0>
# schema_of_variant_agg              function             <function schema_of_varia<...>nt_agg at 0xfff583247e20>
# schema_of_xml                      function             <function schema_of_xml at 0xfff5832505e0>
# sec                                function             <function sec at 0xfff583205a80>
# second                             function             <function second at 0xfff58321bf60>
# sentences                          function             <function sentences at 0xfff58322f920>
# sequence                           function             <function sequence at 0xfff583252340>
# session_user                       function             <function session_user at 0xfff58322d4e0>
# session_window                     function             <function session_window at 0xfff58322c9a0>
# sha                                function             <function sha at 0xfff583269760>
# sha1                               function             <function sha1 at 0xfff58322d9e0>
# sha2                               function             <function sha2 at 0xfff58322db20>
# shiftLeft                          function             <function shiftLeft at 0xfff583218400>
# shiftRight                         function             <function shiftRight at 0xfff583218680>
# shiftRightUnsigned                 function             <function shiftRightUnsigned at 0xfff583218900>
# shiftleft                          function             <function shiftleft at 0xfff583218540>
# shiftright                         function             <function shiftright at 0xfff5832187c0>
# shiftrightunsigned                 function             <function shiftrightunsigned at 0xfff583218a40>
# shuffle                            function             <function shuffle at 0xfff5832513a0>
# sign                               function             <function sign at 0xfff583205d00>
# signum                             function             <function signum at 0xfff583205bc0>
# sin                                function             <function sin at 0xfff583205e40>
# sinh                               function             <function sinh at 0xfff583205f80>
# size                               function             <function size at 0xfff583250ae0>
# skewness                           function             <function skewness at 0xfff583210e00>
# slice                              function             <function slice at 0xfff5832454e0>
# some                               function             <function some at 0xfff5832107c0>
# sort_array                         function             <function sort_array at 0xfff583251120>
# soundex                            function             <function soundex at 0xfff583239260>
# spark                              SparkSession         <pyspark.sql.connect.sess<...>object at 0xfff549b930b0>
# spark_partition_id                 function             <function spark_partition_id at 0xfff583218b80>
# split                              function             <function split at 0xfff583238360>
# split_part                         function             <function split_part at 0xfff58323a3e0>
# sql                                method               <bound method SparkSessio<...>bject at 0xfff549b930b0>>
# sqrt                               function             <function sqrt at 0xfff5831fdbc0>
# stack                              function             <function stack at 0xfff58326a160>
# startswith                         function             <function startswith at 0xfff58323b060>
# std                                function             <function std at 0xfff583207240>
# stddev                             function             <function stddev at 0xfff583207100>
# stddev_pop                         function             <function stddev_pop at 0xfff5832074c0>
# stddev_samp                        function             <function stddev_samp at 0xfff583207380>
# str_to_map                         function             <function str_to_map at 0xfff5832539c0>
# string_agg                         function             <function string_agg at 0xfff5831ff880>
# string_agg_distinct                function             <function string_agg_distinct at 0xfff5831ff9c0>
# string_cols                        list                 n=14
# struct                             function             <function struct at 0xfff583219080>
# substr                             function             <function substr at 0xfff58323a520>
# substring                          function             <function substring at 0xfff58322fa60>
# substring_index                    function             <function substring_index at 0xfff58322fba0>
# sum                                function             <function sum at 0xfff5831fee80>
# sumDistinct                        function             <function sumDistinct at 0xfff5831ff380>
# sum_distinct                       function             <function sum_distinct at 0xfff5831ff4c0>
# table                              method               <bound method SparkSessio<...>bject at 0xfff549b930b0>>
# table_name                         str                  customer
# tan                                function             <function tan at 0xfff5832060c0>
# tanh                               function             <function tanh at 0xfff583206200>
# target_df                          DataFrame            DataFrame[customerid: int<...>ng, source_table: string]
# theta_difference                   function             <function theta_difference at 0xfff5832687c0>
# theta_intersection                 function             <function theta_intersection at 0xfff583268680>
# theta_intersection_agg             function             <function theta_intersect<...>on_agg at 0xfff583262840>
# theta_sketch_agg                   function             <function theta_sketch_agg at 0xfff5832625c0>
# theta_sketch_estimate              function             <function theta_sketch_es<...>timate at 0xfff583268400>
# theta_union                        function             <function theta_union at 0xfff583268540>
# theta_union_agg                    function             <function theta_union_agg at 0xfff583262700>
# time_diff                          function             <function time_diff at 0xfff583223f60>
# time_trunc                         function             <function time_trunc at 0xfff58322c0e0>
# timestamp_add                      function             <function timestamp_add at 0xfff58322c5e0>
# timestamp_diff                     function             <function timestamp_diff at 0xfff58322c4a0>
# timestamp_micros                   function             <function timestamp_micros at 0xfff58322c360>
# timestamp_millis                   function             <function timestamp_millis at 0xfff58322c220>
# timestamp_seconds                  function             <function timestamp_seconds at 0xfff583223e20>
# toDegrees                          function             <function toDegrees at 0xfff583206340>
# toRadians                          function             <function toRadians at 0xfff583206480>
# to_binary                          function             <function to_binary at 0xfff583239da0>
# to_char                            function             <function to_char at 0xfff583239ee0>
# to_csv                             function             <function to_csv at 0xfff5832509a0>
# to_date                            function             <function to_date at 0xfff5832214e0>
# to_json                            function             <function to_json at 0xfff583247f60>
# to_number                          function             <function to_number at 0xfff58323a160>
# to_time                            function             <function to_time at 0xfff583221e40>
# to_timestamp                       function             <function to_timestamp at 0xfff583222160>
# to_timestamp_ltz                   function             <function to_timestamp_ltz at 0xfff58322cc20>
# to_timestamp_ntz                   function             <function to_timestamp_ntz at 0xfff58322cd60>
# to_unix_timestamp                  function             <function to_unix_timestamp at 0xfff58322cae0>
# to_utc_timestamp                   function             <function to_utc_timestamp at 0xfff583223ce0>
# to_varchar                         function             <function to_varchar at 0xfff58323a020>
# to_variant_object                  function             <function to_variant_object at 0xfff5832476a0>
# to_xml                             function             <function to_xml at 0xfff583250720>
# transform                          function             <function transform at 0xfff583252a20>
# transform_keys                     function             <function transform_keys at 0xfff5832534c0>
# transform_values                   function             <function transform_values at 0xfff583253600>
# translate                          function             <function translate at 0xfff583239c60>
# trim                               function             <function trim at 0xfff58322ea20>
# trunc                              function             <function trunc at 0xfff583223240>
# try_add                            function             <function try_add at 0xfff5831fdd00>
# try_aes_decrypt                    function             <function try_aes_decrypt at 0xfff583269620>
# try_avg                            function             <function try_avg at 0xfff5831fde40>
# try_divide                         function             <function try_divide at 0xfff5831fdf80>
# try_element_at                     function             <function try_element_at at 0xfff583245b20>
# try_make_interval                  function             <function try_make_interval at 0xfff5832602c0>
# try_make_timestamp                 function             <function try_make_timestamp at 0xfff583260f40>
# try_make_timestamp_ltz             function             <function try_make_timest<...>mp_ltz at 0xfff5832611c0>
# try_make_timestamp_ntz             function             <function try_make_timest<...>mp_ntz at 0xfff583261940>
# try_mod                            function             <function try_mod at 0xfff5831fe0c0>
# try_multiply                       function             <function try_multiply at 0xfff5831fe200>
# try_parse_json                     function             <function try_parse_json at 0xfff583247560>
# try_parse_url                      function             <function try_parse_url at 0xfff58323a660>
# try_reflect                        function             <function try_reflect at 0xfff583269da0>
# try_subtract                       function             <function try_subtract at 0xfff5831fe340>
# try_sum                            function             <function try_sum at 0xfff5831fe480>
# try_to_binary                      function             <function try_to_binary at 0xfff58323b7e0>
# try_to_date                        function             <function try_to_date at 0xfff583221620>
# try_to_number                      function             <function try_to_number at 0xfff58323b920>
# try_to_time                        function             <function try_to_time at 0xfff583222480>
# try_to_timestamp                   function             <function try_to_timestamp at 0xfff5832225c0>
# try_url_decode                     function             <function try_url_decode at 0xfff58323ab60>
# try_validate_utf8                  function             <function try_validate_utf8 at 0xfff58322f2e0>
# try_variant_get                    function             <function try_variant_get at 0xfff583247ba0>
# try_zstd_decompress                function             <function try_zstd_decompress at 0xfff58326b1a0>
# typeof                             function             <function typeof at 0xfff58326a020>
# ucase                              function             <function ucase at 0xfff583244220>
# udtf                               function             <function udtf at 0xfff58326ae80>
# unbase64                           function             <function unbase64 at 0xfff58322e660>
# unhex                              function             <function unhex at 0xfff583239620>
# uniform                            function             <function uniform at 0xfff583239760>
# unix_date                          function             <function unix_date at 0xfff583221760>
# unix_micros                        function             <function unix_micros at 0xfff5832218a0>
# unix_millis                        function             <function unix_millis at 0xfff5832219e0>
# unix_seconds                       function             <function unix_seconds at 0xfff583221b20>
# unix_timestamp                     function             <function unix_timestamp at 0xfff583223a60>
# unwrap_udt                         function             <function unwrap_udt at 0xfff583261f80>
# upper                              function             <function upper at 0xfff58322e160>
# url_decode                         function             <function url_decode at 0xfff58323aa20>
# url_encode                         function             <function url_encode at 0xfff58323aca0>
# user                               function             <function user at 0xfff58322d3a0>
# validate_utf8                      function             <function validate_utf8 at 0xfff58322f1a0>
# var_pop                            function             <function var_pop at 0xfff583207880>
# var_samp                           function             <function var_samp at 0xfff583207740>
# variance                           function             <function variance at 0xfff583207600>
# variant_get                        function             <function variant_get at 0xfff583247a60>
# version                            function             <function version at 0xfff583269ee0>
# weekday                            function             <function weekday at 0xfff583220220>
# weekofyear                         function             <function weekofyear at 0xfff5832200e0>
# when                               function             <function when at 0xfff5832194e0>
# width_bucket                       function             <function width_bucket at 0xfff583211c60>
# window                             function             <function window at 0xfff58322c720>
# window_time                        function             <function window_time at 0xfff58322c860>
# xpath                              function             <function xpath at 0xfff583222700>
# xpath_boolean                      function             <function xpath_boolean at 0xfff583222840>
# xpath_double                       function             <function xpath_double at 0xfff583222980>
# xpath_float                        function             <function xpath_float at 0xfff583222c00>
# xpath_int                          function             <function xpath_int at 0xfff583222d40>
# xpath_long                         function             <function xpath_long at 0xfff583222e80>
# xpath_number                       function             <function xpath_number at 0xfff583222ac0>
# xpath_short                        function             <function xpath_short at 0xfff583222fc0>
# xpath_string                       function             <function xpath_string at 0xfff583223100>
# xxhash64                           function             <function xxhash64 at 0xfff58322dda0>
# year                               function             <function year at 0xfff58321b420>
# years                              function             <function years at 0xfff583253b00>
# zeroifnull                         function             <function zeroifnull at 0xfff5832691c0>
# zip_with                           function             <function zip_with at 0xfff583253380>
# zstd_compress                      function             <function zstd_compress at 0xfff58326af20>
# zstd_decompress                    function             <function zstd_decompress at 0xfff58326b060>

# %%
spark.sql("SHOW CATALOGS").show()
# Out:
# +---------+
# |  catalog|
# +---------+
# |  samples|
# |   system|
# |workspace|
# +---------+

# %%
df = spark.table("silver.salesorderheader")

# %%
# GOLD LAYER
# 1
from pyspark.sql.functions import sum
customer_sales_df = df_sales_order_header.groupBy("CustomerID") \
    .agg(sum("TotalDue").alias("total_revenue"))
customer_sales_df.show()
# Out:
# +----------+-------------+
# |CustomerID|total_revenue|
# +----------+-------------+
# |         1|    2750.0000|
# |         2|    3526.0000|
# |         3|    2328.0000|
# +----------+-------------+

# %%
# 2
from pyspark.sql.functions import year, month, sum, col
monthly_sales_df = df_sales_order_header \
    .withColumn("order_year", year("OrderDate")) \
    .withColumn("order_month", month("OrderDate")) \
    .groupBy("order_year", "order_month") \
    .agg(sum("TotalDue").alias("monthly_revenue")) \
    .orderBy("order_year", "order_month")

# Display the output
monthly_sales_df.show()
# Out:
# +----------+-----------+---------------+
# |order_year|order_month|monthly_revenue|
# +----------+-----------+---------------+
# |      2026|          2|      8604.0000|
# +----------+-----------+---------------+

# %%
# 3
from pyspark.sql.functions import col, desc
top_10_customers_df = customer_sales_df.orderBy(desc("total_revenue")).limit(10)
top_10_customers_df.show()
# Out:
# +----------+-------------+
# |CustomerID|total_revenue|
# +----------+-------------+
# |         2|    3526.0000|
# |         1|    2750.0000|
# |         3|    2328.0000|
# +----------+-------------+

# %%
# 4
from pyspark.sql.functions import sum, desc
top_products_df = df_sales_order_detail \
    .join(df_product, "ProductID") \
    .groupBy("Name") \
    .agg(sum("LineTotal").alias("product_revenue")) \
    .orderBy(desc("product_revenue")) \
    .limit(10)
top_products_df.show()
# Out:
# +-------------+---------------+
# |         Name|product_revenue|
# +-------------+---------------+
# |    Road Bike|    3200.000000|
# |Mountain Bike|    2500.000000|
# | Touring Bike|    2100.000000|
# | Classic Vest|     190.500000|
# | Sport Helmet|      99.980000|
# +-------------+---------------+

# %%
# 5
from pyspark.sql.functions import sum
sales_by_city_state_df = df_sales_order_header \
    .join(df_customer_address, df_sales_order_header.CustomerID == df_customer_address.CustomerID, "inner") \
    .join(df_address, df_customer_address.AddressID == df_address.AddressID, "inner") \
    .groupBy(df_address.City, df_address.StateProvince) \
    .agg(sum("TotalDue").alias("total_sales")) \
    .orderBy("total_sales", ascending=False)

# %%
# 6
from pyspark.sql.functions import sum
category_revenue_df = df_sales_order_detail \
    .join(df_product, "ProductID") \
    .join(df_product_category, df_product.ProductCategoryID == df_product_category.ProductCategoryID, "inner") \
    .groupBy(df_product_category.Name.alias("category_name")) \
    .agg(sum("LineTotal").alias("category_revenue")) \
    .orderBy("category_revenue", ascending=False)

display(category_revenue_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>category_name</th><th>category_revenue</th></tr></thead><tbody><tr><td>Bikes</td><td>5300.000000</td></tr><tr><td>Mountain Bikes</td><td>2500.000000</td></tr><tr><td>Clothing</td><td>190.500000</td></tr><tr><td>Accessories</td><td>99.980000</td></tr></tbody></table></div>

# %%
# 7
from pyspark.sql.functions import countDistinct
total_orders_per_customer_df = df_sales_order_header.groupBy("CustomerID") \
    .agg(countDistinct("SalesOrderID").alias("total_orders"))

display(total_orders_per_customer_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>CustomerID</th><th>total_orders</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr><tr><td>2</td><td>1</td></tr><tr><td>3</td><td>1</td></tr></tbody></table></div>

# %%
# 8
from pyspark.sql.functions import avg
average_order_value_df = df_sales_order_header.agg(avg("TotalDue").alias("average_order_value"))
display(average_order_value_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>average_order_value</th></tr></thead><tbody><tr><td>2868.00000000</td></tr></tbody></table></div>

# %%
# 9
customers_no_orders_df = df_customer.join(df_sales_order_header, df_customer.CustomerID == df_sales_order_header.CustomerID, "left_anti")
display(customers_no_orders_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>CustomerID</th><th>NameStyle</th><th>Title</th><th>FirstName</th><th>MiddleName</th><th>LastName</th><th>Suffix</th><th>CompanyName</th><th>SalesPerson</th><th>EmailAddress</th><th>Phone</th><th>PasswordHash</th><th>PasswordSalt</th><th>rowguid</th><th>ModifiedDate</th></tr></thead><tbody><tr><td>4</td><td>false</td><td>Mr.</td><td>Janeth</td><td>null</td><td>Esteves</td><td>null</td><td>Modular Cycle Systems</td><td>adventure-works\garrett1</td><td>janeth@example.com</td><td>710-555-0173</td><td>hash4</td><td>salt4</td><td>C4</td><td>2026-01-04T00:00:00.000Z</td></tr><tr><td>5</td><td>false</td><td>Ms.</td><td>Lucy</td><td>null</td><td>Harrington</td><td>null</td><td>Metropolitan Sports</td><td>adventure-works\jillian0</td><td>lucy@example.com</td><td>828-555-0188</td><td>hash5</td><td>salt5</td><td>C5</td><td>2026-01-05T00:00:00.000Z</td></tr></tbody></table></div>

# %%
# 10
products_never_sold_df = df_product.join(df_sales_order_detail, df_product.ProductID == df_sales_order_detail.ProductID, "left_anti")
display(products_never_sold_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ProductID</th><th>Name</th><th>ProductNumber</th><th>Color</th><th>StandardCost</th><th>ListPrice</th><th>Size</th><th>Weight</th><th>ProductCategoryID</th><th>ProductModelID</th><th>SellStartDate</th><th>SellEndDate</th><th>DiscontinuedDate</th><th>ThumbNailPhoto</th><th>ThumbnailPhotoFileName</th><th>rowguid</th><th>ModifiedDate</th></tr></thead><tbody></tbody></table></div>

# %%
# 11
from pyspark.sql.functions import to_date, sum
daily_sales_kpi_df = df_sales_order_header \
    .withColumn("order_date", to_date("OrderDate")) \
    .groupBy("order_date") \
    .agg(sum("TotalDue").alias("daily_revenue")) \
    .orderBy("order_date")

display(daily_sales_kpi_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_date</th><th>daily_revenue</th></tr></thead><tbody><tr><td>2026-02-01</td><td>2750.0000</td></tr><tr><td>2026-02-02</td><td>3526.0000</td></tr><tr><td>2026-02-03</td><td>2328.0000</td></tr></tbody></table></div>

# %%
# 12
from pyspark.sql.functions import year, sum
yearly_revenue_df = df_sales_order_header \
    .withColumn("order_year", year("OrderDate")) \
    .groupBy("order_year") \
    .agg(sum("TotalDue").alias("yearly_revenue")) \
    .orderBy("order_year")

display(yearly_revenue_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_year</th><th>yearly_revenue</th></tr></thead><tbody><tr><td>2026</td><td>8604.0000</td></tr></tbody></table></div>

# %%
# 13
from pyspark.sql.functions import col
sales_with_profit_df = sales_by_city_state_df.withColumn("profit", col("total_sales") * 0.20)

# %%
# 14
from pyspark.sql.functions import sum
customer_lifetime_value_df = df_sales_order_header.groupBy("CustomerID") \
    .agg(sum("TotalDue").alias("customer_lifetime_value"))

display(customer_lifetime_value_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>CustomerID</th><th>customer_lifetime_value</th></tr></thead><tbody><tr><td>1</td><td>2750.0000</td></tr><tr><td>2</td><td>3526.0000</td></tr><tr><td>3</td><td>2328.0000</td></tr></tbody></table></div>

# %%
# 15
from pyspark.sql.functions import countDistinct
repeat_customers_df = df_sales_order_header.groupBy("CustomerID") \
    .agg(countDistinct("SalesOrderID").alias("order_count")) \
    .filter(col("order_count") > 1)

display(repeat_customers_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>CustomerID</th><th>order_count</th></tr></thead><tbody></tbody></table></div>

# %%
# 16
from pyspark.sql.functions import sum, countDistinct

product_performance_df = df_sales_order_detail \
    .join(df_product, "ProductID") \
    .groupBy("ProductID", "Name") \
    .agg(
        sum("LineTotal").alias("revenue"),
        sum("OrderQty").alias("quantity_sold"),
        countDistinct("SalesOrderID").alias("order_count")
    ) \
    .orderBy("revenue", ascending=False)

display(product_performance_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ProductID</th><th>Name</th><th>revenue</th><th>quantity_sold</th><th>order_count</th></tr></thead><tbody><tr><td>2</td><td>Road Bike</td><td>3200.000000</td><td>1</td><td>1</td></tr><tr><td>1</td><td>Mountain Bike</td><td>2500.000000</td><td>1</td><td>1</td></tr><tr><td>3</td><td>Touring Bike</td><td>2100.000000</td><td>1</td><td>1</td></tr><tr><td>5</td><td>Classic Vest</td><td>190.500000</td><td>3</td><td>1</td></tr><tr><td>4</td><td>Sport Helmet</td><td>99.980000</td><td>2</td><td>1</td></tr></tbody></table></div>

# %%
# 17
from pyspark.sql.window import Window
from pyspark.sql.functions import dense_rank

region_sales_window = Window.partitionBy("StateProvince").orderBy(col("total_sales").desc())
region_sales_ranked_df = sales_by_city_state_df.withColumn("region_sales_rank", dense_rank().over(region_sales_window))

# %%
# 18 Find highest revenue month for each year using Window and rank
from pyspark.sql.functions import year, month, sum, col
from pyspark.sql.window import Window
from pyspark.sql.functions import dense_rank
monthly_sales_df = df_sales_order_header \
    .withColumn("order_year", year("OrderDate")) \
    .withColumn("order_month", month("OrderDate")) \
    .groupBy("order_year", "order_month") \
    .agg(sum("TotalDue").alias("monthly_revenue"))
window_spec = Window.partitionBy("order_year").orderBy(col("monthly_revenue").desc())
highest_revenue_month_df = monthly_sales_df.withColumn("month_rank", dense_rank().over(window_spec)) \
    .filter(col("month_rank") == 1)

display(highest_revenue_month_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_year</th><th>order_month</th><th>monthly_revenue</th><th>month_rank</th></tr></thead><tbody><tr><td>2026</td><td>2</td><td>8604.0000</td><td>1</td></tr></tbody></table></div>

# %%
# 19 
from pyspark.sql.functions import to_date
fact_sales_df = df_sales_order_header \
    .join(df_sales_order_detail, "SalesOrderID") \
    .select(
        col("SalesOrderID").alias("sales_order_id"),
        col("CustomerID").alias("customer_key"),
        col("ProductID").alias("product_key"),
        to_date("OrderDate").alias("order_date_key"),
        col("OrderQty"),
        col("UnitPrice"),
        col("UnitPriceDiscount"),
        col("LineTotal"),
        col("TotalDue")
    )

display(fact_sales_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sales_order_id</th><th>customer_key</th><th>product_key</th><th>order_date_key</th><th>OrderQty</th><th>UnitPrice</th><th>UnitPriceDiscount</th><th>LineTotal</th><th>TotalDue</th></tr></thead><tbody><tr><td>1001</td><td>1</td><td>1</td><td>2026-02-01</td><td>1</td><td>2500.0000</td><td>0.0000</td><td>2500.000000</td><td>2750.0000</td></tr><tr><td>1002</td><td>2</td><td>2</td><td>2026-02-02</td><td>1</td><td>3200.0000</td><td>0.0000</td><td>3200.000000</td><td>3526.0000</td></tr><tr><td>1003</td><td>3</td><td>3</td><td>2026-02-03</td><td>1</td><td>2100.0000</td><td>0.0000</td><td>2100.000000</td><td>2328.0000</td></tr><tr><td>1001</td><td>1</td><td>4</td><td>2026-02-01</td><td>2</td><td>49.9900</td><td>0.0000</td><td>99.980000</td><td>2750.0000</td></tr><tr><td>1002</td><td>2</td><td>5</td><td>2026-02-02</td><td>3</td><td>63.5000</td><td>0.0000</td><td>190.500000</td><td>3526.0000</td></tr></tbody></table></div>

# %%
# 20 
from pyspark.sql.functions import max, current_timestamp
gold_audit_summary_df = df_sales_order_header.agg(
    max("OrderDate").alias("max_order_date"),
    current_timestamp().alias("refresh_timestamp"),
    countDistinct("SalesOrderID").alias("order_count"),
    countDistinct("CustomerID").alias("customer_count"),
    countDistinct("SalesOrderNumber").alias("unique_order_numbers")
)

display(gold_audit_summary_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>max_order_date</th><th>refresh_timestamp</th><th>order_count</th><th>customer_count</th><th>unique_order_numbers</th></tr></thead><tbody><tr><td>2026-02-03T00:00:00.000Z</td><td>2026-06-12T04:09:17.883Z</td><td>3</td><td>3</td><td>3</td></tr></tbody></table></div>
