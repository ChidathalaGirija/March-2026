# %% [markdown]
# # Task 1: Add your favorite food

# %%
foods = ["pizza","burger","pasta"]
foods.append("maggie"),foods.append("samosa"),foods.append("nuggets"),foods.append("potato crispy bolls"),foods.append("biryani")
foods
# Out:
# ['pizza',
#  'burger',
#  'pasta',
#  'maggie',
#  'samosa',
#  'nuggets',
#  'potato crispy bolls',
#  'biryani']

# %% [markdown]
# # Task2:Add multiple items

# %%
colors = ["red","blue"]
colors.append("green"),colors.append("yellow")
colors
# Out:
# ['red', 'blue', 'green', 'yellow']

# %% [markdown]
# #Task3: Insert at specific position
# numbers = [1,2,4,5]
# #insert 3 in the correct position

# %%
numbers = [1,2,4,5]
numbers.insert(2,3)
numbers
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# # Task 4: Remove an item
# fruits = ["apple","banana","mango","grapes"]
# # Remove "mango"

# %%
fruits = ["apple","banana","mango","grapes"]
fruits.remove("mango")
fruits
# Out:
# ['apple', 'banana', 'grapes']

# %% [markdown]
# # Task 5: Remove last item
# items = ["pen","book","eraser"]
# # Remove the last item

# %%
items = ["pen","book","eraser"]
items.pop(-1) 
items
# Out:
# ['pen', 'book']

# %% [markdown]
# # Task 6: Find index
# animals = ["cat","dog","lion","tiger"]
# # find  the position of "lion"

# %%
animals = ["cat","dog","lion","tiger"]
position = animals.index("lion")
print(position)
# Out:
# 2

# %% [markdown]
# # Task7: count occurence
# nums = [1,2,2,3,2,4]
# # count how many times 2 appers

# %%
nums = [1,2,2,3,2,4]
occurence = nums.count(2)
print(occurence)
# Out:
# 3

# %% [markdown]
# # Task 8: sort the list
# marks = [85,45,90,60]
# # sort the list in ascending order

# %%
marks = [85,45,90,60]
marks_1 = marks.sort()
marks
# Out:
# [45, 60, 85, 90]

# %% [markdown]
# # Task 9: reverse the list
# letters = ["a","b","c","d"]
# # Reverse the list

# %%
letters = ["a","b","c","d"]
s = letters
print(s[::-1])
# Out:
# ['d', 'c', 'b', 'a']

# %% [markdown]
# # Task 10: copy the list
# original = [10,20,30]
# creat a copy of this list  into a new variable

# %%
original = [10,20,30]
Duplicate = original
print(Duplicate)
# Out:
# [10, 20, 30]

# %% [markdown]
# # Task 11: clear the list
# data = [1,2,3,4]
# # Remove all elements from the list

# %%
data = [1,2,3,4]
data.clear()
data
# Out:
# []

# %% [markdown]
# # Task 12: Extend a list
# list1 = [1,2]
# list2 = [3,4]
# # add all elements of list2 into list1

# %%
list1 = [1,2]
list2 = [3,4]
list1.extend([3,4])
list1
# Out:
# [1, 2, 3, 4]
