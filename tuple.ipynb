# %% [markdown]
# Tuple

# %% [markdown]
# ## creation and slicing and indexing

# %%
empty_tuple = ()
type(empty_tuple)
# Out:
# tuple

# %%
empty_list = []
type(empty_list)
# Out:
# list

# %%
tech_skills = ("python","sql","git","ci/cd","python")
course_info = ("ds101","data science",15,4.8)
tech_skills[-1],tech_skills[:2]
# Out:
# ('python', ('python', 'sql'))

# %% [markdown]
# course_info = ("ds101","data science",15, 4.8)#ID,Name,Weeks,Rating
# # get course name and rating from course_info

# %%
name_rating = course_info[1],course_info[3]
print(name_rating)
type(name_rating)
# Out:
# ('data science', 4.8)
# tuple

# %%
name_rating = course_info[1],course_info[3]
name_rating
# Out:
# ('data science', 4.8)

# %%
name,rating = ("data science",4.8)
name
# Out:
# 'data science'

# %%
name,rating = ("data science",4.8)
rating
# Out:
# 4.8

# %% [markdown]
# # Tuple unpacking

# %%
information = ("girija",22,"madanapalle","data engineering")
information,type(information)
# Out:
# (('girija', 22, 'madanapalle', 'data engineering'), tuple)

# %%
name,age,city,course = information
name
# Out:
# 'girija'

# %%
name,age,city,course = information
age
# Out:
# 22

# %%
name,age,city,course = information
city
# Out:
# 'madanapalle'

# %%
name,age,city,course = information
course
# Out:
# 'data engineering'

# %%
information = ("girija",22,"madanapalle","data engineering")
city,course,name,age, = information
city
# Out:
# 'girija'

# %%
information = ("girija",22,"madanapalle","data engineering")
city,course,name,age, = information
course
# Out:
# 22

# %%
information = ("girija",22,"madanapalle","data engineering")
city,course,name,age, = information
name
# Out:
# 'madanapalle'

# %%
information = ("girija",22,"madanapalle","data engineering")
city,course,name,age, = information
age
# Out:
# 'data engineering'

# %%
information = ("girija",22,"madanapalle","data engineering")
city,course,name,age, = information
information
# Out:
# ('girija', 22, 'madanapalle', 'data engineering')

# %%
information = ("girija",22,"madanapalle","data engineering")
information[1],information[0],information[2]
# Out:
# (22, 'girija', 'madanapalle')

# %% [markdown]
# ## creating tuple without paranthesis

# %%
student_record = "arvika",18,"data engineering"
student_record
# Out:
# ('arvika', 18, 'data engineering')

# %%
student_record = "arvika",18,"data engineering"
type(student_record)
# Out:
# tuple

# %%
name, roll_no, course = student_record
name
# Out:
# 'arvika'

# %%
name, roll_no, course = student_record
roll_no
# Out:
# 18

# %%
name, roll_no, course = student_record
course
# Out:
# 'data engineering'

# %% [markdown]
# tuple.count(item)

# %%
tech_skills = ("python","sql","git","ci/cd","python","sql","python")
ratings = (5,4,5,4,3,2,5)

# %% [markdown]
# ### how many python in this tuple

# %%
tech_skills = ("python","sql","git","ci/cd","python","sql","python")
tech_skills.count("python")
# Out:
# 3

# %%
tech_skills = ("python","sql","git","ci/cd","python","sql","python")
tech_skills.count("sql")
# Out:
# 2

# %% [markdown]
# ## how many 5 rating in tuple

# %%
tech_skills = ("python","sql","git","ci/cd","python","sql","python")
ratings = (5,4,5,4,3,2,5)
ratings.count(5)
# Out:
# 3

# %% [markdown]
# ## count in a tuple with nested tuples

# %%
nested=(1,(2,3),4,(2,3),4,4,4,4,4,44444)
nested.count(4)
# Out:
# 6

# %%
nested=(1,(2,3),4,(2,3),4,4,4,4,4,44444)
nested.count(0)
# Out:
# 0

# %% [markdown]
#  tuple.index(item,start,end)

# %%
tech_skills = ("python","sql","git","ci/cd","python","sql","python")
ratings = (5,4,5,4,3,2,5)
tech_skills.index("sql",2)
# Out:
# 5

# %%
tech_skills = ("python","sql","git","ci/cd","python","sql","python")
ratings = (5,4,5,4,3,2,5)
tech_skills.index("python",1)
# Out:
# 4

# %%
tech_skills = ("python","sql","git","ci/cd","python","sql","python")
ratings = (5,4,5,4,3,2,5)
tech_skills.index("python",5)
# Out:
# 6
