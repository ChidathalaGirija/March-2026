# %% [markdown]
# # Question 1: Calculate the product of first 10 natural numbers

# %%
product = 1 
for i in range(1,11):
    product = product*i
    print(product)
# Out:
# 1
# 2
# 6
# 24
# 120
# 720
# 5040
# 40320
# 362880
# 3628800

# %% [markdown]
# Question 2: Find the remainder when 156 is divided by 7

# %%
X = 156
Y = 7
print(156 % 7)
# Out:
# 2

# %% [markdown]
# Question 3: Calculate the square of 25

# %%
X = 25 
print(25** 2)
# Out:
# 625

# %% [markdown]
# Question 4: Calculate the sum of digits in number 12345

# %%
digits = [1,2,3,4,5]
print(sum(digits))
# Out:
# 15

# %% [markdown]
# Question 4: Find the cube root of 125

# %%
a = 125
print(125**3)
# Out:
# 1953125

# %% [markdown]
# # Question 6: Check if 97 is a prime number

# %%
num = 97
for i in range(2,num):
    if num % i == 0:
        print("not prime")
        break
        
    else:
        print("prime")
# Out:
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime

# %% [markdown]
# # Question 7: Find the factorial of 8

# %%
num = 8
fact = 1
for i in range (1,num+1):
    fact = fact*i
    print(fact)
# Out:
# 1
# 2
# 6
# 24
# 120
# 720
# 5040
# 40320

# %% [markdown]
# Question 8: Calculate the average of numbers: 15, 23, 31, 42, 56

# %%
numbers = [15,23,31,42,56]
avg = sum (numbers)/len(numbers)
print(avg)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 2
#       1 numbers = [15,23,31,42,56]
# ----> 2 avg = sum (numbers)/len(numbers)
#       3 print(avg)
#
# TypeError: 'list' object is not callable

# %% [markdown]
#  Find the greatest common divisor (GCD) of 48 and 36

# %%
import math
print(math.gcd(48,36))
# Out:
# 12

# %% [markdown]
# Calculate the sum of first 20 odd numbers

# %%
n = 20
sum_odd = n*n 
print(sum_odd)
# Out:
# 400
