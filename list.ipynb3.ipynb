# %% [markdown]
# Way to remove elements from the list
#  list.remove(item)

# %% [markdown]
# course_list = ["python basics","data science","cloud intro","data engineering","data science"]
# tools = ["python","sql","git","sql"]

# %%
# remove cloud  intro
course_list = ["python basics","data science","cloud intro","data engineering","data science"]
course_list.remove("cloud intro")
course_list
# Out:
# ['python basics', 'data science', 'data engineering', 'data science']

# %%
course_list = ["python basics","data science","cloud intro","data engineering","data science"]
course_list.remove("cloud intro")
course_list.remove("data science")
course_list
# Out:
# ['python basics', 'data engineering', 'data science']

# %%
tools = ["python","sql","git","sql"]
tools.remove("python")
tools
# Out:
# ['sql', 'git', 'sql']

# %%
tools = ["python","sql","git","sql"]

tools.remove("sql")
tools
# Out:
# ['python', 'git', 'sql']

# %%
student_counts = [350,420,720,910]
student_counts.remove(420)
student_counts
# Out:
# [350, 720, 910]

# %% [markdown]
# ## list.pop([index])

# %%
course_list = ["python basics","data science","data engineering"]
tasks = ["review code","update docs","deploy"] 
# pop the last item (default index-1)
last_course = course_list.pop()
last_course
# Out:
# 'data engineering'

# %%
course_list = ["python basics","data science","data engineering"]
tasks = ["review code","update docs","deploy"] 
# pop the last item (default index-1)
last_course = course_list.pop()
course_list
# Out:
# ['python basics', 'data science']

# %%
course_list = ["python basics","data science","data engineering"]
first_course = course_list.pop(0)
course_list
# Out:
# ['data science', 'data engineering']

# %%
course_list = ["python basics","data science","data engineering"]
second_course = course_list.pop(1)
course_list
# Out:
# ['python basics', 'data engineering']

# %%
tasks = ["review code","update docs","deploy"]
last_tasks = tasks.pop()
tasks
# Out:
# ['review code', 'update docs']

# %%
tasks = ["review code","update docs","deploy"]
first_tasks = tasks.pop(0)
tasks
# Out:
# ['update docs', 'deploy']

# %%
tasks = ["review code","update docs","deploy"]
first_tasks = tasks.pop(0),tasks.pop(1),tasks.pop(-1)
tasks,type(tasks)
# Out:
# ([], list)

# %%
tasks = ["review code","update docs","deploy"]
first_1_tasks = tasks.pop(10)
tasks
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[37], line 2
#       1 tasks = ["review code","update docs","deploy"]
# ----> 2 first_1_tasks = tasks.pop(10)
#       3 tasks
#
# IndexError: pop index out of range

# %% [markdown]
# ## list.clear()

# %%
course_list = ["python basics","data science","data engineering"]
course_list.clear()
course_list
# Out:
# []

# %%
tasks = ["review code","update docs","deploy"]
tasks.clear()
tasks
# Out:
# []

# %% [markdown]
# sorting the list
# list.sort(key=None,reverse=False)

# %%
course_list = ["python basics","data science","data engineering"]
student_counts = [350,420,380]
mixed_case_courses = ["azure devops","python basics","data analytics"]

# %% [markdown]
# ## sort course list alphabetically(in place)

# %%
course_list = ["python basics","data science","data engineering"]
course_list.sort()
course_list
# Out:
# ['data engineering', 'data science', 'python basics']

# %%
alpha_list = ["Z","A","B","Q","C","D","H"]
alpha_list.sort()
alpha_list
# Out:
# ['A', 'B', 'C', 'D', 'H', 'Q', 'Z']

# %%
alpha_list = ['A', 'B', 'C', 'D', 'H', 'Q', 'Z']
alpha_list.sort(reverse=True)
alpha_list
# Out:
# ['Z', 'Q', 'H', 'D', 'C', 'B', 'A']

# %% [markdown]
# # sort mixed cases courses case insensitively

# %%
mixed_case_courses = ["azure devops","python basics","data analytics"]
mixed_case_courses.sort(key=str.upper)
mixed_case_courses
# Out:
# ['azure devops', 'data analytics', 'python basics']

# %% [markdown]
# # sort based on len
# courses = ["sql","python","azure devops","git"]

# %%
courses = ["sql","python","azure devops","git"]
courses.sort(key=len)
courses
# Out:
# ['sql', 'git', 'python', 'azure devops']

# %% [markdown]
# Membership Testing(in,not in)
# checks if an item exists within the list
# return true or false..

# %%
course_list = ["python basics","data science","data engineering"]
tech_skill = ["sql","python","azure devops","git"]

# %% [markdown]
# ## check if "data science" is in course list

# %%
course_list = ["python basics","data science","data engineering"]
is_de_in_list = "data engineering" in course_list
is_de_in_list
# Out:
# True

# %% [markdown]
# ## check for ml

# %%
course_list = ["python basics","data science","data engineering"]
is_ml_in_list = "machine learning" in course_list
is_ml_in_list
# Out:
# False

# %% [markdown]
# #  check python with not in

# %%
tech_skill = ["sql","python","azure devops","git"]
"python" not in tech_skill
# Out:
# False

# %%
tech_skill = ["sql","python","azure devops","git"]
"ml" not in tech_skill
# Out:
# True

# %%
tech_skill = ["sql","python","azure devops","git"]
len(tech_skill)
# Out:
# 4
