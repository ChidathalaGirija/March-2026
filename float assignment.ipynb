# %% [markdown]
# Question 1: Calculate the average of 3.14, 2.718, 1.618, 0.577

# %%
numbers = [3.14,2.718,1.18,0.77]
avg = sum(numbers)/len(numbers)
print(avg)
# Out:
# 1.952

# %% [markdown]
#  Question 2: Convert 98.6 Fahrenheit to Celsius (F = C * 9/5 + 32)

# %%
celsius = 98.6
F=98.6*9/5+32
print(F)
# Out:
# 209.48

# %% [markdown]
# Question 3: Calculate the compound interest on $1000 at 5.5% for 3 years

# %%
p = 1000
t = 3
r = 0.055
n = 1
result = p*(1+r/n)*t
print(result)
# Out:
# 3165.0

# %% [markdown]
# Question 4: Find the hypotenuse of a right triangle with sides 3.5 and 4.2

# %%
a = 3.5
b = 4.2
result = (a**2 + b**2)**0.5
print(result)
# Out:
# 5.4671747731346585

# %% [markdown]
# Question 5: Calculate the volume of a sphere with radius 7.8

# %%
r = 7.8
result = (4/3)*(22/7)*(7.8**2)
print(result)
# Out:
# 254.94857142857137

# %% [markdown]
#  Question 6: Round 3.14159 to 3 decimal places

# %%
value = 3.14159
value_place_3dp = round(value,3)
print(value_place_3dp)
# Out:
# 3.142

# %% [markdown]
# Question 7: Calculate the percentage: 45 out of 67

# %%
percentage = (45/67)*100
print(percentage)
# Out:
# 67.16417910447761

# %% [markdown]
#  Question 8: Find the square root of 23.456

# %%
number = 23.456
result =(23.456**2)
print(result)
# Out:
# 550.183936

# %% [markdown]
#  Question 9: Calculate the simple interest: Principal=2500, Rate=6.5%, Time=2.5 years

# %%
p = 2500
t = 2.5
r = 0.065
result = (p*t*r)/100
print(result)
# Out:
# 4.0625

# %% [markdown]
#  Question 10: Convert 45.7 degrees to radians

# %%
import math
degree = 45.7
radians = math.radians(degree)
print(radians)
# Out:
# 0.7976154681614086
